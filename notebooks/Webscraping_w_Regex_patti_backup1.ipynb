# %% [markdown]
# ## Webscraping Exercise
#
# The purpose of this exercise is to use *beautifulsoup* to extract out information from this article: https://www.usatoday.com/story/money/business/2018/09/13/mcdonalds-states-most-stores/37748287/.
#
# Unfortunately, the information we want is not stored in a table and is not formatted in a way that makes it easy to extract, so it will take some work before you can do any analysis.
#
# Your objective is to create a pandas DataFrame containing all 50 states and the four metrics from the article (number of McDonald's per 100,000, adult obesity rate, percent consuming vegetables less than daily, and median household income).

# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %% [markdown]
# **Step 1: Use _requests_ to fetch the contents of the article and convert to soup with _BeautifulSoup_**

# %%
# Your code here
url = 'https://www.usatoday.com/story/money/business/2018/09/13/mcdonalds-states-most-stores/37748287/'
response = requests.get(url)

# %% [markdown]
# ### Step 2: Extract State Names

# %% [markdown]
# **A.** Using whatever method you would like, extract out the states as a list named `states`. Do this in the same order that they appear in the article.

# %%
# Your code here
soup = bs(response.text)

# %% [markdown]
# **B.** Now, extract the other four variables as lists named `McD`, `obesity`, `veggies`, and `income`. Make sure that they are in the same order as states.

# %%
# Your code here
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="gnt__njs" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1" name="viewport"/>
#   <meta content="#0098FE" name="theme-color"/>
#   <title>
#    McDonald's lover? Here are the states with the most stores
#   </title>
#   <meta content="Is your state 'lovin' it'? A look at where the most McDonald's are located in the US" property="og:title"/>
#   <link href="https://amp.usatoday.com/amp/37748287" rel="amphtml"/>
#   <meta content="Colman Andrews" property="article:author"/>
#   <meta content="metered" property="article:content_tier"/>
#   <meta content="false" property="article:opinion"/>
#   <link href="//user.usatoday.com" rel="dns-prefetch"/>
#   <link href="https://user.usatoday.com" rel="preconnect"/>
#   <link href="//content-static.gannett.com" rel="dns-prefetch"/>
#   <link href="//www.gannett-cdn.com" rel="dns-prefetch"/>
#   <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="//adservice.google.com" rel="dns-prefetch"/>
#   <link href="https://adservice.google.com" rel="preconnect"/>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
#   <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//s0.2mdn.net" rel="dns-prefetch"/>
#   <link href="//partner.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="https://www.googletagservices.com" rel="preconnect"/>
#   <link href="//static.adsafeprotected.com" rel="dns-prefetch"/>
#   <link href="https://static.adsafeprotected.com" rel="preconnect"/>
#   <link href="//pixel.adsafeprotected.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://pixel.adsafeprotected.com" rel="preconnect"/>
#   <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//c.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//js-sec.indexww.com" rel="dns-prefetch"/>
#   <link href="https://js-sec.indexww.com" rel="preconnect"/>
#   <link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//aax.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/>
#   <link href="https://fastlane.rubiconproject.com" rel="preconnect"/>
#   <link href="//bidder.criteo.com" rel="dns-prefetch"/>
#   <link href="https://bidder.criteo.com" rel="preconnect"/>
#   <link href="//static.criteo.com" rel="dns-prefetch"/>
#   <link href="//colossusssp.com" rel="dns-prefetch"/>
#   <link href="https://colossusssp.com" rel="preconnect"/>
#   <link href="//gannett-d.openx.net" rel="dns-prefetch"/>
#   <link href="https://gannett-d.openx.net" rel="preconnect"/>
#   <link href="//hbopenbid.pubmatic.com" rel="dns-prefetch"/>
#   <link href="https://hbopenbid.pubmatic.com" rel="preconnect"/>
#   <link href="//ads.pubmatic.com" rel="dns-prefetch"/>
#   <link href="//as-sec.casalemedia.com" rel="dns-prefetch"/>
#   <link href="https://as-sec.casalemedia.com" rel="preconnect"/>
#   <link href="//ib.adnxs.com" rel="dns-prefetch"/>
#   <link href="https://ib.adnxs.com" rel="preconnect"/>
#   <link href="//adserver.adtechus.com" rel="dns-prefetch"/>
#   <link href="https://adserver.adtechus.com" rel="preconnect"/>
#   <link href="//apex.go.sonobi.com" rel="dns-prefetch"/>
#   <link href="https://apex.go.sonobi.com" rel="preconnect"/>
#   <link href="//sofia.trustx.org" rel="dns-prefetch"/>
#   <link href="https://sofia.trustx.org" rel="preconnect"/>
#   <link href="//tlx.3lift.com" rel="dns-prefetch"/>
#   <link href="https://tlx.3lift.com" rel="preconnect"/>
#   <link href="//e.serverbid.com" rel="dns-prefetch"/>
#   <link href="https://e.serverbid.com" rel="preconnect"/>
#   <link href="//confiant-integrations.global.ssl.fastly.net" rel="dns-prefetch"/>
#   <link href="https://confiant-integrations.global.ssl.fastly.net" rel="preconnect"/>
#   <link href="https://s0.2mdn.net" rel="preconnect"/>
#   <link href="https://media.gannett-cdn.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://media.gannett-cdn.com" rel="preconnect"/>
#   <link href="https://ads.adaptv.advertising.com" rel="preconnect"/>
#   <link href="https://search.spotxchange.com" rel="preconnect"/>
#   <link href="https://static.adsafeprotected.com" rel="preconnect"/>
#   <link href="https://imasdk.googleapis.com" rel="preconnect"/>
#   <link href="//ads.adaptv.advertising.com" rel="dns-prefetch"/>
#   <link href="//search.spotxchange.com" rel="dns-prefetch"/>
#   <link href="//static.adsafeprotected.com" rel="dns-prefetch"/>
#   <link href="//imasdk.googleapis.com" rel="dns-prefetch"/>
#   <link href="//geolocation.onetrust.com" rel="dns-prefetch"/>
#   <link href="https://geolocation.onetrust.com" rel="preconnect"/>
#   <link href="//cdn.taboola.com" rel="dns-prefetch"/>
#   <link href="https://cdn.taboola.com" rel="preconnect"/>
#   <link href="//trc.taboola.com" rel="dns-prefetch"/>
#   <link href="https://trc.taboola.com" rel="preconnect"/>
#   <link href="//www.usatodaynetworkservice.com" rel="dns-prefetch"/>
#   <link as="fetch" crossorigin="use-credentials" href="https://user.usatoday.com/USAT-GUP/user/" rel="preload" type="application/json"/>
#   <link as="script" href="/tangstatic/js/pbjsandwich-q1a2z3dc41a7be.min.js" rel="preload"/>
#   <link as="script" href="https://c.amazon-adsystem.com/aax2/apstag.js" rel="preload"/>
#   <link as="script" href="https://js-sec.indexww.com/ht/p/184808-89514051626416.js" rel="preload"/>
#   <link as="script" href="https://static.adsafeprotected.com/iasPET.1.js" rel="preload"/>
#   <link as="script" crossorigin="" href="https://static.criteo.net/js/ld/publishertag.prebid.js" rel="preload"/>
#   <link as="script" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preload"/>
#   <link as="script" href="https://confiant-integrations.global.ssl.fastly.net/r5TdgVvkbv-PeaJCKaQfCh5Xsto/gpt_and_prebid_v3l/config.js" rel="preload"/>
#   <link as="script" href="/tangstatic/js/main-q1a2z3f986af3c.min.js" rel="preload"/>
#   <link as="script" href="https://geolocation.onetrust.com/cookieconsentpub/v1/geo/location/gnt.otgc" rel="preload"/>
#   <link as="script" href="https://cdn.taboola.com/libtrc/usatodaydemo/loader.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/controls-a72d7ef9.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/share-454f9438.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/tealplayer-5aa8c51e.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/teal-comscore-f1701de9.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/teal-gcianalytics-4c420e9b.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/teal-hls-ec6a0617.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/encore-c29e248c.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/teal-ima-a1174258.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/vendor/hls/hls.0.14.9.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/vendor/comscore/streamsense-5.1.1.160316.min.js" rel="preload"/>
#   <link as="script" href="/gannett-web/apps/teal/dist/vendor/ias/ias-3.5.1.min.js" rel="preload"/>
#   <link as="script" href="https://s0.2mdn.net/instream/video/client.js" rel="preload"/>
#   <link as="script" href="https://imasdk.googleapis.com/js/sdkloader/ima3.js" rel="preload"/>
#   <meta content="McDonald’s is America’s largest hamburger chain with about 14,000 stores in the U.S. The concentration of restaurants varies considerably by state." name="description"/>
#   <meta content="McDonald’s is America’s largest hamburger chain with about 14,000 stores in the U.S. The concentration of restaurants varies considerably by state." property="og:description"/>
#   <meta content="13652355666,48958576760,156345381090801,110471702456365,6566864515,137698179626815,315942225236045,927427260614748,183850168300771,1443524575938047,251228454889939,158095147555989,115535341805950,236655713446291,1621466394844549,250325640686,177037772444433,1972936962947967,2047091012096533,535551216797440" property="fb:pages"/>
#   <meta content="215046668549694" property="fb:app_id"/>
#   <link href="https://247wallst.com/special-report/2018/09/07/states-with-the-most-mcdonalds-2" rel="canonical"/>
#   <meta content="https://www.usatoday.com/story/money/business/2018/09/13/mcdonalds-states-most-stores/37748287/" property="og:url"/>
#   <meta content="USA TODAY" property="og:site_name"/>
#   <meta content="https://www.gannett-cdn.com/-mm-/97c04198b93024709b947d878e17e45707aec4a4/c=0-296-4121-2624/local/-/media/2018/06/04/USATODAY/USATODAY/636637268331067900-AP-Salute-To-Summer-Parade.jpg?width=3200&amp;height=1808&amp;fit=crop&amp;format=pjpg&amp;auto=webp" property="og:image"/>
#   <meta content="3200" property="og:image:width"/>
#   <meta content="1808" property="og:image:height"/>
#   <meta content="NOODP, NOYDIR" name="ROBOTS"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="article" property="og:type"/>
#   <script>
#    "use strict";{const c=window.FontFace,b=document,d="url(data:application/font-woff2;charset=utf-8;base64,...) format('woff2')";
# if(c){const a=new c("Unify Sans",d,{display:"optional",weight:"700"});a.load();b.fonts.add(a)}else{const a=b.createElement("style");a.innerHTML='@font-face{font-family:"Unify Sans";src:'+d+";font-display:optional;font-weight:700}";b.head.appendChild(a)}};
# {const c=window,b=document,g=navigator,d=g.userAgent,a={};c.gnt={u:{},v:{},a7s:{dq:[],tq:[]},now:Date.now(),bn:{}};(a.t=(a.ip=a.i=1<g.maxTouchPoints&&d.includes("c OS X")&&
# !d.includes("(iP"))||(a.tn=(a.a=d.includes("; And"))||(a.in=a.i=d.includes("(iP"))))||(a.e=d.includes("Edge"));;c.g$={run:[],d:b,de:b.documentElement,ec:encodeURIComponent,jp:JSON.parse,js:JSON.stringify,aeld:EventTarget.prototype.addEventListener,cached:{windowInnerHeight:innerHeight,windowInnerWidth:innerWidth},b:a,nv:g,ua:d,vv:c.visualViewport,el:{debounce:function(r){let l=-250,h;return function(a){if(!h){const b=a.timeStamp-l;250<b?(l=a.timeStamp,r(a)):h=setTimeout(()=>
# {h=0;l+=250;r(a)},250-b)}}}},intersectionObserverSupported:"IntersectionObserverEntry"in c&&"isIntersecting"in IntersectionObserverEntry.prototype}}try{if(g$.ls=window.localStorage)g$.ss=sessionStorage,gnt.storage=!0}catch(c){}
# (function(){function c(b,c){let d={};if(b&&"string"===typeof b){c||(c="&");let g=b.charCodeAt(0);var a=0;let l;if("&"===c){if(63===g||35===g)a=1;for(;b.charAt(a)===c;)++a}for(;;){for(;" "===b.charAt(a);)++a;g=b.indexOf("=",a);let h=b.indexOf(c,a);if(0<g&&(g<h||-1===h))if(a=b.substring(a,g),0<h)for(d[a]=b.substring(g+1,a=h);b.charAt(++a)===c;);else{d[a]=b.substr(g+1);break}else if(0<h&&(h<g||-1===g))for(d[b.substring(a,h)]=!0,a=h+1;(l=b.charAt(a))===c||" "===l;)++a;else{a<b.length&&(d[b.substr(a)]=
# !0);break}}}return d}g$.parseQS=c;g$.hp=g$.hashParams=c(location.hash);g$.qsp=g$.qsParams=c(location.search);g$.ic=g$.initCookies=c(document.cookie,";")})();;
# if(g$.b.t&&!g$.hp["gnt-disable-vu"]){let c;const b=g$.vv,g=function(d){(c||(c=document.querySelector("meta[name=viewport]"))).content="width="+d};if(b&&g$.b.a){let c="device-width";b.addEventListener("resize",function(){var a=Math.round(b.width*b.scale);a=1024>=a?1024:1200<=a?1200:"device-width";c!==a&&g(c=a)})}else(1024>screen.width||1024>screen.height)&&g(1024)};;
# gnt.luxEnabled=performance.mark&&(.02>Math.random()||g$.hp["gnt-enable-lux"])&&!g$.hp["gnt-disable-lux"];(g$.ut=performance.mark&&(gnt.luxEnabled||g$.hp["gnt-perf"])?c=>{performance.mark(c)}:()=>{})("gnt head");;
# {const c=g$,{hp:b,ic:g,d,de:a}=c,{"gnt-user-cookiesMissing":r,"gnt-user-status":l,"gnt-user-ccpaout":h}=b,m=g.gup_lng,p=gnt,f=p.u;let e;if(m)try{e=f.lng=JSON.parse(decodeURIComponent(m))}catch(G){}e||(e=f.lng={auth:!1,hma:!1,lic:"none",name:"","ret-sub":!1,"ret-user":!1,nfc:!0});const q=a.classList,w=l&&"string"===typeof l,x="sub"===l,z=x||"reg"===l,D=!(f.cm="boolean"===typeof r?r:!g.gup_lsid&&!z),n=f.au=w?z:D&&e.auth,E=f.hma=w?x:n&&e.hma,u=f.lt=b["gnt-user-licensetype"]||e.lic,C=f.wn=b["gnt-user-welcomename"]||
# e.name;f.rs=b["gnt-user-retsub"]||e["ret-sub"];f.ru=e["ret-user"];;f.rs&&(q.add("gnt__hnb"),p.hnb=!0);if((f.su="scroll0"in g)||n&&u&&u.endsWith("plus"))p.hnb=f.adfree=!0,q.add("gnt__hx","gnt__hnb");;
# n&&C&&(a.style.setProperty("--gnt-uwn","'"+C+"'"),a.setAttribute("data-u-n",""));a.setAttribute("data-u-s",f.s=n?E?"sub":"reg":"anon");;if(!b["gnt-disable-ccpa"]){let a,b,c=";path=/;secure;samesite=lax;priority=high;max-age=31536000",
# e=g.OptanonConsent,k=g.usprivacy;if(p.storage){const a=localStorage,b=a.getItem("gnt.u.oc");if(!e&&b)d.cookie="OptanonConsent="+(e=b)+";domain=usatoday.com"+c;else if(e&&e!==b)try{a.setItem("gnt.u.oc",e)}catch(B){}}const l=Object.defineProperty,m=e&&e.length&&(-1<e.indexOf("on=US%3BCA")||-1<e.indexOf("on=US%3BNV"))?-1<(a=e.indexOf("groups="))&&(-1<(a="%2C"+e.substr(a+7)).indexOf("%2C4%3A0")||-1<a.indexOf("%2C5%3A0"))?2:1:0,n=f.co=h||2===m||k&&k[2]&&"Y"===k[2].toUpperCase(),r=function(v,
# A,B){if("getUSPData"===v&&"function"===typeof B)try{B({uspString:b,version:1},!0)}catch(H){}},q=function(){d.cookie="usprivacy="+b+c};k!==(b=m||k&&"1---"!==k?n?"1YYY":"1YNY":"1---")&&q();try{l(p,"usp",{enumerable:!0,get:function(){return b},set:function(v){b===v||h||(f.co="1YYY"===(b=v),q())}}),l(window,"__uspapi",{enumerable:!0,value:r})}catch(v){}}};
#   (g$.nv.share||g$.hp["gnt-enable-shareapi"])&&document.documentElement.setAttribute("data-ss-sa","");
#
#
#   g$.de.classList.remove("gnt__njs");
#
# ;;
# gnt.v.sp=!0;try{Object.defineProperty(window,"_sp_",{value:{config:{account_id:308}}})}catch(c){};
#   </script>
#   <style>
#    @font-face{font-family:'Unify Sans';src:local('☺︎')}@media not all and (min-resolution:.001dpcm){@media{@font-face{font-family:'Unify Sans';src:local('Helvetica Neue')}}}html{margin:0;padding:0;background:#fff;overflow-y:scroll;-webkit-text-size-adjust:none;text-size-adjust:none}body{overflow:visible!important;margin:0;padding:0;background:unset;font:10px/13px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}img:not([src]):not([srcset]){visibility:hidden}img:-moz-loading{visibility:hidden}:focus{outline-color:#0098fe}.gnt_cw{display:flex;flex-wrap:wrap;align-items:stretch;width:980px;margin:20px auto 0;padding:0 10px;flex-shrink:0;position:relative;background:#fff}.gnt_pr{width:660px;margin-right:auto}.gnt_rr{contain:layout;overflow-anchor:none;width:300px;--gnt-x-nbh:80px}@media (min-width:1200px){.gnt_cw{align-content:start;width:1020px;min-height:480px;margin:30px auto 0;padding:0 60px}}.gnt_ar_hl{margin:6px 0 0;color:#303030;font:700 36px/38px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_bc{min-width:1000px;height:20px;margin:0 0 -20px;background:linear-gradient(150deg,#00553c,50%,#3cc37d)}@media (min-width:1200px){.gnt_bc{height:480px;margin:0 0 -480px}}.gnt_cw_w{isolation:isolate;display:flex;justify-content:space-between;min-width:1000px}.gnt_cw_sl{overflow-anchor:none;width:calc(50% - 500px);outline:0}.gnt_cw_sl__ed{order:3}.gnt_xbr{display:none}@media (min-width:1200px){.gnt_cw_sl{width:calc(50% - 570px)}.gnt_xbr{overflow-anchor:none;display:block;width:0}.gnt_ar_xb{display:inline-block;position:-webkit-sticky;position:sticky;top:267px;transform:translate(36px,-58px);width:36px;height:36px;margin:0 0 -17px;border:4px solid #fff;border-radius:50%;background:#303030}.gnt__hx .gnt_ar_xb{transform:translate(36px,-92px)}.gnt__hnb .gnt_ar_xb{top:187px}.gnt_ar_xb::before{content:'';position:absolute;top:17px;left:10px;transform:rotate(45deg);width:16px;height:2px;background:#fff}.gnt_ar_xb::after{content:'';position:absolute;top:17px;left:10px;transform:rotate(-45deg);width:16px;height:2px;background:#fff}.gnt_ar_xb:hover{background:#000}}html:not(.gnt__njs) .gnt__hbd{display:none;background:unset}.gnt_ft{width:880px;height:722px;margin:-10px auto 0;padding:0 10px;color:#303030;-webkit-user-select:none;user-select:none}.gnt_ft_lw{display:flex;justify-content:space-between;margin:56px 0 -513px}.gnt_ft_ls{display:flex;flex-flow:column;width:150px}.gnt_ft_ls::before{content:attr(aria-label);margin:0 0 -1px;font:700 14px/16px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_ft_a{margin:16px auto 0 -2px;padding:0 2px;border:0;background:0 0;color:#303030;font:14px/18px 'Georgia Pro',Georgia,'Droid Serif',serif;text-decoration:none;text-align:left;cursor:pointer}.gnt_ft_a:hover{color:#000}.gnt_ft_a__bl{font-weight:700}.gnt_ft_cr{padding:542px 0 58px;font:12px/14px 'Georgia Pro',Georgia,'Droid Serif',serif;text-align:center}@media (min-width:1200px){.gnt_ft{padding:0 60px}}.gnt_x{margin:46px auto}.gnt_x_sl{contain:content;transform:translate3d(0,0,0);width:300px;min-height:250px;background-color:#f8f8f8;margin:auto;position:relative}.gnt_x__lbl::before{content:var(--gnt-x-lbl, 'Advertisement');text-align:center;color:#787878;font:10px/18px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;display:block}.gnt_x__lh::before{opacity:0}.gnt_x__st{position:-webkit-sticky;position:sticky;top:200px;margin-top:32px}.gnt__hnb .gnt_x__st{top:120px}.gnt_x_sl__st{transform:unset;will-change:unset}.gnt_x_lb{contain:strict;overflow:hidden;transform:translate3d(0,0,0);width:728px;height:90px;background-color:#f8f8f8;margin:auto}.gnt__hx .gnt_tb,.gnt__hx .gnt_x{display:none}.gnt_x__hi{contain:layout;margin:6px auto 18px;padding:0;--gnt-x-lbl:'Advertisement - scroll for more content'}.gnt_x_hi{width:970px;height:250px;display:flex;align-items:center;justify-content:center}.gnt_x_hi__wd{width:1140px;height:515px}.gnt_x_hi_bkf{display:block;left:0;margin:auto;border:0}.gnt_x__pf{margin:0 aut ...
#   </style>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://www.gannett-cdn.com/-mm-/97c04198b93024709b947d878e17e45707aec4a4/c=0-296-4121-2624/local/-/media/2018/06/04/USATODAY/USATODAY/636637268331067900-AP-Salute-To-Summer-Parade.jpg?width=1600&amp;height=800&amp;fit=crop&amp;format=pjpg&amp;auto=webp" name="twitter:image"/>
#   <meta content="@usatoday" name="twitter:site"/>
#   <meta content="@usatoday" name="twitter:creator"/>
#   <meta content="Is your state 'lovin' it'? A look at where the most McDonald's are located in the US" name="twitter:title"/>
#   <meta content="McDonald’s is America’s largest hamburger chain with about 14,000 stores in the U.S. The concentration of restaurants varies considerably by state." name="twitter:description"/>
#  </head>
#  <body>
#   <svg style="display:none">
#    <symbol id="gnt_svg_external" viewbox="0 0 18 18">
#     <path d="M12.43 5.5H10.5V4H15v4.5h-1.5V6.55l-4.56 4.56-1.06-1.06 4.55-4.55zm1.07 9v-3.75H15V16H3V4h5.25v1.5H4.5v9h9z">
#     </path>
#    </symbol>
#    <svg id="gnt_svg_share_facebook" style="fill:var(--gnt-sfc,#4460a0)" viewbox="0 0 24 24">
#     <path d="M10.5932 20.9998C6.291 20.3204 3 16.5743 3 12.055 3 7.054 7.0294 3 12 3s9 4.054 9 9.0549c0 4.5198-3.2914 8.266-7.5943 8.9451v-6.3188h2.097l.3991-2.6175h-2.496v-1.6985c0-.716.3486-1.414 1.4666-1.414h1.1349V6.7227s-1.03-.1769-2.0146-.1769c-2.0558 0-3.3995 1.2536-3.3995 3.523v1.9948H8.3081v2.6175h2.2851v6.3186z">
#     </path>
#    </svg>
#    <symbol id="gnt_svg_share_twitter" style="fill:var(--gnt-sfc,#00aaec)" viewbox="0 0 24 24">
#     <path d="M21 6.776a7.213 7.213 0 0 1-2.12.596 3.778 3.778 0 0 0 1.623-2.095 7.273 7.273 0 0 1-2.346.918A3.642 3.642 0 0 0 15.462 5c-2.038 0-3.692 1.696-3.692 3.787 0 .296.032.585.095.862-3.069-.158-5.79-1.664-7.612-3.958a3.856 3.856 0 0 0-.5 1.906c0 1.313.652 2.472 1.643 3.152a3.626 3.626 0 0 1-1.673-.473v.047c0 1.835 1.273 3.366 2.963 3.713-.31.089-.636.133-.973.133-.238 0-.47-.023-.695-.067.47 1.504 1.833 2.599 3.45 2.628A7.292 7.292 0 0 1 3 18.3 10.282 10.282 0 0 0 8.66 20c6.794 0 10.508-5.77 10.508-10.774 0-.164-.003-.329-.01-.49A7.58 7.58 0 0 0 21 6.776">
#     </path>
#    </symbol>
#    <symbol id="gnt_svg_share_email" style="fill:var(--gnt-sfc,#626262)" viewbox="0 0 24 24">
#     <path d="M3 5.88c0-.49.4-.88.9-.88h16.2c.5 0 .9.4.9.88v12.24c0 .49-.4.88-.9.88H3.9a.9.9 0 0 1-.9-.88V5.88zm9 5.21L3 6.74v1.74l9 4.35 9-4.35V6.74l-9 4.35z">
#     </path>
#    </symbol>
#    <symbol id="gnt_svg_shareapi" style="fill:var(--gnt-sfc,#000)" viewbox="0 0 24 24">
#     <path d="M14 5l6 7-6 7V5zm0 4v6c-1.937-.271-3.937.062-6 1s-3.73 2.271-5 4c.909-3.576 2.242-6.242 4-8s4.091-2.758 7-3z">
#     </path>
#    </symbol>
#    <symbol id="gnt_svg_video_play" viewbox="0 0 84 84">
#     <circle cx="40.5" cy="40.5" fill="#303030" r="38" stroke="#0098FE" stroke-width="4">
#     </circle>
#     <path d="M56 40.23l-22.5 13.5v-27z" fill="#FFF">
#     </path>
#    </symbol>
#   </svg>
#   <header class="gnt_n" onmousedown="event.stopPropagation()" onmouseup="event.stopPropagation()">
#    <div class="gnt_n_lg_w">
#     <button aria-label="Skip to main content" class="gnt_n_sb" data-g-r="base_sb" data-t-l="${tc}|H1Nav|skipToMainContent">
#     </button>
#     <a aria-label="USA TODAY" class="gnt_n_lg" data-t-l="|H1Nav|logo" href="/">
#      <svg class="gnt_n_lg_svg" viewbox="0 2 78 28">
#       <circle cx="14" cy="16" fill="#009bff" r="14">
#       </circle>
#       <path d="M36 12.75a1.53 1.53 0 0 0 1.18-.45 1.82 1.82 0 0 0 .38-1.3V5.43h2.53V11A3.7 3.7 0 0 1 39 13.85a4.29 4.29 0 0 1-3 1 4.28 4.28 0 0 1-3-1A3.7 3.7 0 0 1 31.84 11V5.43h2.53V11a1.81 1.81 0 0 0 .42 1.28 1.52 1.52 0 0 0 1.21.47zm9.14 2.11a6.09 6.09 0 0 1-2.14-.39 5.26 5.26 0 0 1-1.8-1.11l1.22-1.54a4.17 4.17 0 0 0 1.22.77 3.89 3.89 0 0 0 1.5.28 1.64 1.64 0 0 0 .86-.19.63.63 0 0 0 .31-.57.67.67 0 0 0-.37-.59 5.35 5.35 0 0 0-1.3-.52l-.57-.15a4 4 0 0 1-1.9-1 2.35 2.35 0 0 1-.65-1.71 2.65 2.65 0 0 1 .48-1.5 3 3 0 0 1 1.28-1 4.64 4.64 0 0 1 1.89-.36 5.38 5.38 0 0 1 2 .39 5.82 5.82 0 0 1 1.71 1.03l-1.26 1.59a5.07 5.07 0 0 0-1.15-.73 3 3 0 0 0-1.31-.31 1.58 1.58 0 0 0-.84.18A.6.6 0 0 0 44 8a.7.7 0 0 0 .31.56 3.15 3.15 0 0 0 1.08.44l.69.19a4.25 4.25 0 0 1 2.11 1.12 2.42 2.42 0 0 1 .62 1.65 2.65 2.65 0 0 1-.46 1.54 3 3 0 0 1-1.29 1 4.73 4.73 0 0 1-1.92.36zm11.32-.18L55.87 13h-3.46l-.58 1.73h-2.5l3.39-9.25h2.94l3.34 9.2zM53 11.08h2.19l-1.04-3.24zM34.59 26.53v-7.21h-2.75v-2h8v2h-2.72v7.21zM45.16 26.71a4.92 4.92 0 0 1-2.47-.61A4.49 4.49 0 0 1 41 24.4a4.87 4.87 0 0 1-.63-2.48 5.15 5.15 0 0 1 .34-1.92 4.48 4.48 0 0 1 1-1.52 4.61 4.61 0 0 1 1.52-1 5.38 5.38 0 0 1 3.83 0 4.62 4.62 0 0 1 1.52 1 4.47 4.47 0 0 1 1 1.52 5.13 5.13 0 0 1 .42 1.92 4.87 4.87 0 0 1-.62 2.48 4.49 4.49 0 0 1-1.71 1.69 4.92 4.92 0 0 1-2.51.62zm0-2.09a2 2 0 0 0 1.16-.34 2.3 2.3 0 0 0 .78-.95 3.26 3.26 0 0 0 .29-1.41 3.31 3.31 0 0 0-.29-1.41 2.35 2.35 0 0 0-.78-1 2.12 2.12 0 0 0-2.33 0 2.35 2.35 0 0 0-.78 1 3.31 3.31 0 0 0-.29 1.41 3.26 3.26 0 0 0 .29 1.41 2.3 2.3 0 0 0 .78.95 2 2 0 0 0 1.17.33zm6.25 1.91v-9.25h3.65a4.88 4.88 0 0 1 2.43.59 4.31 4.31 0 0 1 1.65 1.63 5.12 5.12 0 0 1 0 4.8 4.31 4.31 0 0 1-1.65 1.63 4.88 4.88 0 0 1-2.43.59zm2.49-2h1.16a1.91 1.91 0 0 0 1.57-.72 3 3 0 0 0 .58-1.9 3 3 0 0 0-.58-1.9 1.91 1.91 0 0 0-1.57-.72H53.9zm13.3 2l-.58-1.73h-3.47l-.58 1.73h-2.5l3.39-9.25h2.94l3.39 9.25zm-3.41-3.6H66l-1.09-3.24zm10.88.27v3.33H72.1V23.2l-3.28-5.92h2.86L73.39 21l1.7-3.67h2.86z" fill="#404040">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="gnt_n_fl gnt_n_nc__hbn">
#     <a class="gnt_n_fl_l" data-c-lbl="INVESTING ADVICE" data-t-l="|top-flag1|money|Investing advice|4 moves before 🗳️" href="/story/money/investing/2020/10/23/4-key-investing-moves-to-make-before-the-november-election/42853061/">
#      4 moves before 🗳️
#     </a>
#     <a class="gnt_n_fl_l" data-c-lbl="COVID EFFECTS" data-t-l="|top-flag2|money|COVID effects|Changing careers 🔄" href="/story/money/2020/10/22/jobs-near-me-unemployed-workers-find-work-these-fields-amid-covid/3714756001/">
#      Changing careers 🔄
#     </a>
#     <a class="gnt_n_fl_l" data-c-lbl="TRUMP'S CLAIM" data-t-l="|top-flag3|money|Trump's claim|Can you prepay taxes?" href="/story/money/2020/10/23/can-you-prepay-taxes-trump-claims-he-did-but-can-pay-irs-upfront/6007203002/">
#      Can you prepay taxes?
#     </a>
#     <a class="gnt_n_fl_l gnt_n_fl_l__li" data-c-lbl="UNEMPLOYMENT 💵" data-t-l="|top-flag4|money|Unemployment 💵|Racial disparity 📈" href="/story/money/2020/10/22/stimulus-check-black-unemployment-rate-racial-disparity-coronavirus-trump-biden/3650844001/">
#      Racial disparity 📈
#     </a>
#    </div>
#    <div class="gnt_n_sm gnt_n_nc__hbn">
#     <a class="gnt_n_sm_a" data-t-l="|H1Nav|headersubscribecallout" data-u-sr="anon reg" elementtiming="nav-submsg" href="https://subscribe.usatoday.com/specialoffer?gps-source=CPMASTHEAD&amp;itm_campaign=2020SLJ&amp;itm_medium=ONSITE&amp;onSuccessRedirectURL=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F" rel="noopener" target="_blank">
#      <div class="gnt_n_sm_a_pt">
#       SUBSCRIBE NOW
#      </div>
#      Only $4.99 per month
#     </a>
#    </div>
#    <nav aria-label="Global navigation" class="gnt_n_mn">
#     <a class="gnt_n_mn_l gnt_n_mn_l__fi gnt_n_mn_ce" data-t-l="|H1Nav|news" elementtiming="nav-item" href="/news/">
#      News
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|sports" href="/sports/">
#      Sports
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|entertainment" href="/entertainment/">
#      Entertainment
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|life" href="/life/">
#      Life
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce gnt_n_mn_l__se" data-t-l="|H1Nav|money" href="/money/">
#      Money
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|tech" href="/tech/">
#      Tech
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|travel" href="/travel/">
#      Travel
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|opinion" href="/opinion/">
#      Opinion
#     </a>
#     <div class="gnt_n_dd_w" data-g-r="nav_ce nav_sh">
#      <button aria-expanded="false" aria-haspopup="true" aria-label="Global Navigation" class="gnt_n_dd_bt gnt_n_mn_ce" data-g-ltn="navgd" data-g-r="nav_ab" data-g-tn="navgdp" data-t-l="${tc}|H1Nav|caret">
#       <svg class="gnt_n_dd_bt_svg" viewbox="0 0 10 6">
#        <path d="M5 3.35L8.64 0 10 1.4 5 6 0 1.4 1.36 0z">
#        </path>
#       </svg>
#      </button>
#     </div>
#     <div class="gnt_n_us">
#      <div class="gnt_n_se" data-g-r="nav_ce">
#       <a aria-expanded="false" aria-haspopup="true" aria-label="Search" class="gnt_n_se_a gnt_n_mn_ce" data-g-r="nav_ab" data-g-tn="navse" data-t-l="${tc}|H1Nav|search" href="/search/" title="Search">
#        <svg class="gnt_n_se_a_svg" viewbox="0 0 24 24">
#         <path d="M15.75 14.33l4.96 4.96-1.42 1.42-4.96-4.96a6.5 6.5 0 1 1 1.41-1.41zM10.5 15a4.5 4.5 0 1 0 0-9 4.5 4.5 0 0 0 0 9z">
#         </path>
#        </svg>
#       </a>
#      </div>
#      <a class="gnt_n_us_sb" data-t-l="|H1Nav|subscribe" data-u-sr="anon reg" elementtiming="nav-subbt" href="https://subscribe.usatoday.com/specialoffer?gps-source=CPTOPNAVBAR&amp;itm_campaign=2020SLJ&amp;itm_medium=ONSITE&amp;onSuccessRedirectURL=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F" rel="noopener" target="_blank">
#       Subscribe
#      </a>
#      <div class="gnt_n_us_a_w" data-g-r="nav_ce">
#       <a aria-expanded="false" aria-haspopup="true" aria-label="Sign In" class="gnt_n_us_a gnt_n_mn_ce" data-g-r="nav_ab" data-g-tn="navus" data-t-l="${tc}|H1Nav|account" href="https://login.usatoday.com/USAT-GUP/authenticate?success-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F&amp;cancel-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F">
#        <svg class="gnt_n_us_a_svg" viewbox="0 0 10 6">
#         <path d="M5 3.35L8.64 0 10 1.4 5 6 0 1.4 1.36 0z">
#         </path>
#        </svg>
#       </a>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <aside aria-label="advertisement" class="gnt_m gnt_x gnt_x__nb" data-x-fc="gnt_x_nbf" data-x-src="https://securepubads.g.doubleclick.net/gampad/adx?t=position%3Dconsumer_sales-nano_bar&amp;iu=7103%2Fusatoday%2Fconsumer_sales-nano_bar%2Fmoney%2Fbusiness&amp;sz=1025x80&amp;cust_params=cst_section%3Dmoney%26cst_subsection%3Dbusiness%26pageType%3Dstory%26contentid%3D37748287%26property%3DUSAT%26sitepage%3DUSAT%2Fmoney%2Fbusiness%26ssts_section%3Dmoney%26ssts_subsection%3Dbusiness%26topic%3Dmcdonalds%2Chealthy-eating%2Cresearch%2Chealth-fanaticism%2Ccommitment%2Camusement%2Chappiness%2Coverall-positive%2Cdisease%2Cmedical-research%2Cdiabetes%2Cchildrens-health%2Cburger-king-worldwide" data-x-sx="consumer_sales-nano_bar">
#   </aside>
#   <aside aria-label="advertisement" class="gnt_m gnt_x gnt_x__lbl gnt_x__hi">
#    <div class="gnt_x_sl gnt_x_hi" id="ad-slot-7103-usatoday-high_impact-money-business-1">
#    </div>
#   </aside>
#   <div class="gnt_bc">
#   </div>
#   <div class="gnt_cw_w">
#    <a aria-hidden="true" aria-label="Close" class="gnt_cw_sl" data-g-r="base_xbutton" data-t-l="|modalclose|overlay" href="/money/" tabindex="-1">
#    </a>
#    <a aria-hidden="true" aria-label="Close" class="gnt_cw_sl gnt_cw_sl__ed" data-g-r="base_xbutton" data-t-l="|modalclose|overlay" href="/money/" tabindex="-1">
#    </a>
#    <main class="gnt_cw">
#     <div aria-label="Business" class="gnt_ar_lbl" data-c-ssts="BUSINESS">
#     </div>
#     <article class="gnt_pr">
#      <h1 class="gnt_ar_hl" elementtiming="ar-headline">
#       Is your state 'lovin' it'? A look at where the most McDonald's are located in the US
#      </h1>
#      <div class="gnt_ar_by">
#       Colman Andrews
#      </div>
#      <div class="gnt_ar_pb">
#       24/7 Wall Street
#      </div>
#      <div aria-label="Published: 5:00 a.m. ET Sep. 13, 2018 Updated: 12:21 p.m. ET Sep. 13, 2018" class="gnt_ar_dt">
#      </div>
#      <div class="gnt_ss" data-g-r="base_sc" data-ss-d="McDonald’s is America’s largest hamburger chain with about 14,000 stores in the U.S. The concentration of restaurants varies considerably by state." data-ss-t="Is your state 'lovin' it'? A look at where the most McDonald's are located in the US" data-ss-u="https://www.usatoday.com/story/money/business/2018/09/13/mcdonalds-states-most-stores/37748287/">
#       <a aria-label="Share to Facebook" class="gnt_ss_a" data-g-r="base_si" data-ss-a="f" data-t-l="${tc}|navbar-share-top|facebook" href="https://www.facebook.com/dialog/share?display=popup&amp;app_id=215046668549694&amp;href=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F" rel="noreferrer">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_share_facebook">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="Share to Twitter" class="gnt_ss_a" data-g-r="base_si" data-ss-a="t" data-t-l="${tc}|navbar-share-top|twitter" href="http://twitter.com/share?url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F&amp;text=Is%20your%20state%20'lovin'%20it'%3F%20A%20look%20at%20where%20the%20most%20McDonald's%20are%20located%20in%20the%20US&amp;via=usatoday" rel="noreferrer">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_share_twitter">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="Share by email" class="gnt_ss_a" data-t-l="${tc}|navbar-share-top|email" href="mailto:?subject=Is%20your%20state%20'lovin'%20it'%3F%20A%20look%20at%20where%20the%20most%20McDonald's%20are%20located%20in%20the%20US%20-%20from%20USA%20TODAY&amp;body=Is%20your%20state%20'lovin'%20it'%3F%20A%20look%20at%20where%20the%20most%20McDonald's%20are%20located%20in%20the%20US%0A%0AMcDonald%E2%80%99s%20is%20America%E2%80%99s%20largest%20hamburger%20chain%20with%20about%2014%2C000%20stores%20in%20the%20U.S.%20The%20concentration%20of%20restaurants%20varies%20considerably%20by%20state.%0A%0ACheck%20out%20this%20story%20on%20usatoday.com%3A%20https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_share_email">
#         </use>
#        </svg>
#       </a>
#       <button aria-label="Share natively" class="gnt_ss_a gnt_ss_a__sa" data-g-r="base_si" data-ss-a="s" data-t-l="${tc}|navbar-share-top|shareapi">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_shareapi">
#         </use>
#        </svg>
#       </button>
#      </div>
#      <div class="gnt_ar_b">
#       <aside aria-label="Video - Fast food chains' buzzword: Sustainability" class="gnt_em gnt_em__fp gnt_em_vp__tp gnt_em__el">
#        <div aria-live="polite" class="gnt_em_vp_w" data-c-vt="teal" data-g-r="vp_tp" data-t-pl="teal-hero">
#         <button aria-label="Play video" class="gnt_em_vp_a gnt_em_vp__tp_a" data-c-vpattrs='{"muted":true,"xprp":1,"bContent":false,"an":"usatoday","pn":"USA TODAY","vidNum":1,"docking":true}' data-c-vpdata="{&quot;adsEnabled&quot;:true,&quot;awsPath&quot;:&quot;money/business&quot;,&quot;byline&quot;:&quot;Video by Robert Hanashiro, USA TODAY&quot;,&quot;canonicalURL&quot;:&quot;&quot;,&quot;contentSourceCode&quot;:&quot;USAT&quot;,&quot;createDate&quot;:&quot;2018-05-22T05:18:09Z&quot;,&quot;credit&quot;:&quot;Video by Robert Hanashiro, USA TODAY&quot;,&quot;duration&quot;:60010,&quot;headline&quot;:&quot;&quot;,&quot;hlsURL&quot;:&quot;&quot;,&quot;id&quot;:&quot;35212121&quot;,&quot;image&quot;:{&quot;url&quot;:&quot;https://media.gannett-cdn.com/29906170001/29906170001_5785947044001_5785924094001-vs.jpg?pubId=29906170001&quot;,&quot;opto&quot;:true},&quot;initialPublishDate&quot;:&quot;2018-05-22T05:18:09Z&quot;,&quot;keywords&quot;:&quot;McDonald's&quot;,&quot;mp4URL&quot;:&quot;https://media.gannett-cdn.com/29906170001/29906170001_5785945921001_5785924094001.mp4&quot;,&quot;origin&quot;:&quot;1&quot;,&quot;pageURL&quot;:{&quot;long&quot;:&quot;https://www.usatoday.com/videos/money/business/2018/05/22/fast-food-chains-buzzword-sustainability/35212121/&quot;},&quot;promoBrief&quot;:&quot;Chains like Starbucks, McDonald's and Dunkin' Donuts are getting on the bandwagon to cutdown on packaging waste.&quot;,&quot;propertyName&quot;:&quot;USATODAY&quot;,&quot;publishDate&quot;:&quot;2018-05-22T05:18:09Z&quot;,&quot;series&quot;:&quot;&quot;,&quot;ssts&quot;:{&quot;section&quot;:&quot;money&quot;,&quot;subsection&quot;:&quot;business&quot;,&quot;topic&quot;:&quot;&quot;,&quot;subtopic&quot;:&quot;&quot;},&quot;tags&quot;:[{&quot;id&quot;:&quot;1dadab21-811a-413f-ab63-1f5f23fd0c4c&quot;,&quot;name&quot;:&quot;Starbucks&quot;},{&quot;id&quot;:&quot;878611e2-a190-4812-b073-cd81fa07fad5&quot;,&quot;name&quot;:&quot;McDonald's&quot;}],&quot;title&quot;:&quot;Fast food chains' buzzword: Sustainability&quot;,&quot;url&quot;:&quot;/videos/money/business/2018/05/22/fast-food-chains-buzzword-sustainability/35212121/&quot;}" data-g-r="vp_ap vp_tg">
#          <svg class="gnt_em_vp_svg">
#           <use xlink:href="#gnt_svg_video_play">
#           </use>
#          </svg>
#         </button>
#         <div class="gnt_em_vp_c">
#          <button aria-label="Close docked video player" class="gnt_em_vp_db" data-t-l="${tc}|tealplayer|playerClose">
#           <svg viewbox="0 0 16 16">
#            <path d="M9 7.625L13.125 3.5 14.5 4.875 10.375 9l4.125 4.125-1.375 1.375L9 10.375 4.875 14.5 3.5 13.125 7.625 9 3.5 4.875 4.875 3.5 9 7.625z">
#            </path>
#           </svg>
#          </button>
#          <div class="teal-video-wrap">
#           <video elementtiming="ar-lead-video" muted="" playsinline="" poster="https://media.gannett-cdn.com/29906170001/29906170001_5785947044001_5785924094001-vs.jpg?pubId=29906170001&amp;width=660&amp;height=371&amp;format=pjpg&amp;auto=webp" title="Fast food chains' buzzword: Sustainability">
#           </video>
#          </div>
#         </div>
#        </div>
#        <div class="gnt_em_vt" data-c-et="Fast food chains' buzzword: Sustainability">
#        </div>
#        <div aria-label="Chains like Starbucks, McDonald's and Dunkin' Donuts are getting on the bandwagon to cutdown on packaging waste." class="gnt_em_vb gnt_em_vb__te" data-c-credit="Video by Robert Hanashiro, USA TODAY">
#        </div>
#       </aside>
#       <p class="gnt_ar_b_p">
#        <asset-img uniqueid="247WallSt.com-247WS-491026-a0dcc61c">
#        </asset-img>
#       </p>
#       <figure class="gnt_em gnt_em_img">
#        <img alt="A flag flies behind the golden arches of a McDonald's restaurant in La Vista, Neb., Friday, May 25, 2018." class="gnt_em_img_i" data-g-r="lazy" data-gl-src="https://www.gannett-cdn.com/-mm-/97c04198b93024709b947d878e17e45707aec4a4/c=0-296-4121-2624/local/-/media/2018/06/04/USATODAY/USATODAY/636637268331067900-AP-Salute-To-Summer-Parade.jpg?width=660&amp;height=373&amp;fit=crop&amp;format=pjpg&amp;auto=webp" data-gl-srcset="https://www.gannett-cdn.com/-mm-/97c04198b93024709b947d878e17e45707aec4a4/c=0-296-4121-2624/local/-/media/2018/06/04/USATODAY/USATODAY/636637268331067900-AP-Salute-To-Summer-Parade.jpg?width=1320&amp;height=746&amp;fit=crop&amp;format=pjpg&amp;auto=webp 2x" decoding="async" style="height:373px"/>
#        <div class="gnt_em_img_ccw gnt_em_img_ccw__cap gnt_em_img_ccw__crd" data-c-caption="A flag flies behind the golden arches of a McDonald's restaurant in La Vista, Neb., Friday, May 25, 2018." data-c-credit="Nati Harnik, AP">
#        </div>
#       </figure>
#       <p class="gnt_ar_b_p">
#        McDonald’s (NYSE: MCD) isn’t America’s largest fast food chain – there are only about 14,000 stores around the country, as opposed to more than 25,000 Subway outlets. It is, however, the largest hamburger chain by far – its nearest competitor, Burger King, has only about 7,500 stores – and the most iconic.
#       </p>
#       <p class="gnt_ar_b_p">
#        Using data collected from the McDonald’s website, 24/7 Wall Street has identified the number of McDonald’s locations in every state. The tally ranges from 25 in North Dakota to 1,295 in California. The concentration of McDonald's restaurants also varies considerably.
#       </p>
#       <p class="gnt_ar_b_p">
#        Five of the 10 states with the highest concentrations of McDonald’s per 100,000 residents – West Virginia, Arkansas, Kentucky, Oklahoma, and Michigan – are also among the 10 states with the highest rates of obesity. However, there is virtually no research that establishes a causative link between the availability of Big Macs and Quarter Pounders – or any other fast food – and adverse health outcomes.
#       </p>
#       <p class="gnt_ar_b_p">
#        A 2011 study in The Journal of Rural Health, for instance, found an association (though not a causative link) between fast food outlets and negative health outcomes in metropolitan areas but not in a rural setting. In 2013, a National Heart, Lung, and Blood Institute’s CARDIA (Coronary Artery Risk Development in Young Adults) study found no association between BMI (body mass index) and density of fast food restaurants and convenience stores. In a systematic review of some 46 studies published between 2005 and 2015 on the relationship between a fast food environment and obesity rates in the United States and abroad by The Journal of Obesity and Weight Loss Therapy, the overwhelming majority found little or no consistent correlation between obesity and fast food.
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong class="gnt_ar_b_al">
#         More:
#        </strong>
#        <a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/restaurants/2018/08/25/cities-where-people-go-out-to-eat-all-the-time/37543531/">
#         U.S. cities where people go out to eat all the time
#        </a>
#       </p>
#       <p class="gnt_ar_b_p">
#        On the other hand, a study published in 2015 by two researchers from the Geospatial Sciences Center of Excellence at South Dakota State University discovered that populations in urban settings served primarily by full-service restaurants and grocery stores had a lower obesity rate than those where fast food places and convenience stores predominated.
#       </p>
#       <p class="gnt_ar_b_p">
#        It is important to remember, though, that there are many other factors other than restaurant choices that may also contribute to obesity and other potentially diet-linked conditions such as cardiovascular disease and diabetes. Low income, high poverty rates, and relative unavailability of fresh fruits and vegetables also contribute to unhealthy lives.
#       </p>
#       <aside aria-label="Video - 5 ways McDonald's tricks you into ordering more food" class="gnt_em gnt_em_vp__tp gnt_em__el">
#        <div aria-live="polite" class="gnt_em_vp_w" data-c-vt="teal" data-g-r="vp_tp" data-t-pl="teal-storyinline">
#         <button aria-label="Play video" class="gnt_em_vp_a gnt_em_vp__tp_a" data-c-vpattrs='{"muted":false,"xprp":1,"bContent":false,"an":"usatoday","pn":"USA TODAY","vidNum":2}' data-c-vpdata="{&quot;adsEnabled&quot;:true,&quot;awsPath&quot;:&quot;money/business&quot;,&quot;byline&quot;:&quot;Buzz60&quot;,&quot;canonicalURL&quot;:&quot;&quot;,&quot;contentSourceCode&quot;:&quot;BZ60&quot;,&quot;createDate&quot;:&quot;2018-03-29T14:30:50Z&quot;,&quot;credit&quot;:&quot;Buzz60&quot;,&quot;duration&quot;:79573,&quot;headline&quot;:&quot;&quot;,&quot;hlsURL&quot;:&quot;&quot;,&quot;id&quot;:&quot;33380479&quot;,&quot;image&quot;:{&quot;url&quot;:&quot;https://media.gannett-cdn.com/29906170001/29906170001_5760346498001_5760345568001-vs.jpg?pubId=29906170001&quot;,&quot;opto&quot;:true},&quot;initialPublishDate&quot;:&quot;2018-03-29T14:30:50Z&quot;,&quot;keywords&quot;:&quot;McDonald's,Fast food industry&quot;,&quot;mp4URL&quot;:&quot;https://media.gannett-cdn.com/29906170001/29906170001_5760343300001_5760345568001.mp4&quot;,&quot;origin&quot;:&quot;Buzz60&quot;,&quot;pageURL&quot;:{&quot;long&quot;:&quot;https://www.usatoday.com/videos/money/business/2018/03/29/5-ways-mcdonalds-tricks-you-into-ordering-more-food/33380479/&quot;},&quot;promoBrief&quot;:&quot;McDonald's uses a number of subliminal techniques to get you to spend more at their restaurants.&quot;,&quot;propertyName&quot;:&quot;USATODAY&quot;,&quot;publishDate&quot;:&quot;2018-03-29T14:30:50Z&quot;,&quot;series&quot;:&quot;&quot;,&quot;ssts&quot;:{&quot;section&quot;:&quot;money&quot;,&quot;subsection&quot;:&quot;business&quot;,&quot;topic&quot;:&quot;&quot;,&quot;subtopic&quot;:&quot;&quot;},&quot;tags&quot;:[{&quot;id&quot;:&quot;878611e2-a190-4812-b073-cd81fa07fad5&quot;,&quot;name&quot;:&quot;McDonald's&quot;},{&quot;id&quot;:&quot;fe714c6c-6183-4156-98e3-80a67ea5dcae&quot;,&quot;name&quot;:&quot;Fast food industry&quot;}],&quot;title&quot;:&quot;5 ways McDonald's tricks you into ordering more food&quot;,&quot;url&quot;:&quot;/videos/money/business/2018/03/29/5-ways-mcdonalds-tricks-you-into-ordering-more-food/33380479/&quot;}" data-g-r="vp_tg">
#          <img alt="" class="gnt_em_vp_img" data-g-r="lazy vp_po" data-gl-src="https://media.gannett-cdn.com/29906170001/29906170001_5760346498001_5760345568001-vs.jpg?pubId=29906170001&amp;width=660&amp;height=371&amp;format=pjpg&amp;auto=webp" data-gl-srcset="https://media.gannett-cdn.com/29906170001/29906170001_5760346498001_5760345568001-vs.jpg?pubId=29906170001&amp;width=1320&amp;height=742&amp;format=pjpg&amp;auto=webp 2x" decoding="async"/>
#          <svg class="gnt_em_vp_svg">
#           <use xlink:href="#gnt_svg_video_play">
#           </use>
#          </svg>
#         </button>
#        </div>
#        <div class="gnt_em_vt" data-c-et="5 ways McDonald's tricks you into ordering more food">
#        </div>
#        <div aria-label="McDonald's uses a number of subliminal techniques to get you to spend more at their restaurants." class="gnt_em_vb gnt_em_vb__te" data-c-credit="Buzz60">
#        </div>
#       </aside>
#       <h3 class="gnt_ar_b_h2">
#        50. Rhode Island
#       </h3>
#       <p class="gnt_ar_b_p">
#        •
#        <strong>
#         No. of McDonald's:
#        </strong>
#        2.9 per 100,000
#        <br/>
#        <strong>
#         • Adult obesity rate:
#        </strong>
#        27.2 percent (17th lowest)
#        <br/>
#        <strong>
#         • Pct. consuming vegetables less than daily:
#        </strong>
#        23.5 percent (20th highest)
#        <br/>
#        <strong>
#         • Median household income:
#        </strong>
#        $60,596 (18th highest)
#       </p>
#       <h3 class="gnt_ar_b_h2">
#        49. New Jersey
#       </h3>
#       <p class="gnt_ar_b_p">
#        <strong>
#         • No. of McDonald's:
#        </strong>
#        3.0 per 100,000
#        <br/>
#        <strong>
#         • Adult obesity rate:
#        </strong>
#        25.9 percent (12th lowest)
#        <br/>
#        <strong>
#         • Pct. consuming vegetables less than daily:
#        </strong>
#        22.1 percent (25th lowest)
#        <br/>
#        <strong>
#         • Median household income:
#        </strong>
#        $76,126 (3rd highest)
#       </p>
#       <p class="gnt_ar_b_p">
#        <asset-img uniqueid="247WallSt.com-247WS-491026-cb98b531">
#        </asset-img>
#       </p>
#       <h3 class="gnt_ar_b_h2">
#        48. New York
#       </h3>
#       <p class="gnt_ar_b_p">
#        <strong>
#         • No. of McDonald's:
#        </strong>
#        3.1 per 100,000
#        <br/>
#        <strong>
#         • Adult obesity rate:
#        </strong>
#        25.0 percent (8th lowest)
#        <br/>
#        <strong>
#         • Pct. consuming vegetables less than daily:
#        </strong>
#        22.4 percent (23rd highest)
#        <br/>
#        <strong>
#         • Median household income:
#        </strong>
#        $62,909 (14th highest)
#       </p>
#       <h3 class="gnt_ar_b_h2">
#        47. California
#       </h3>
#       <p class="gnt_ar_b_p">
#        <strong>
#         • No. of McDonald's:
#        </strong>
#        3.3 per 100,000
#        <br/>
#        <strong>
#         • Adult obesity rate:
#        </strong>
#        22.7 percent (3rd lowest)
#        <br/>
#        <strong>
#         • Pct. consuming vegetables less than daily:
#        </strong>
#        18.6 percent (9th lowest)
#        <br/>
#        <strong>
#         • Median household income:
#        </strong>
#        $67,739 (9th highest)
#       </p>
#       <p class="gnt_ar_b_p">
#        <asset-img uniqueid="247WallSt.com-247WS-491026-79392738">
#        </asset-img>
#       </p>
#       <h3 class="gnt_ar_b_h2">
#        46. North Dakota
#       </h3>
#       <p class="gnt_ar_b_p">
#        <strong>
#         • No. of McDonald's:
#        </strong>
#        3.3 per 100,000
#        <br/>
#        <strong>
#         • Adult obesity rate:
#        </strong>
#        31.8 percent (12th highest)
#        <br/>
#        <strong>
#         • Pct. consuming vegetables less than daily:
#        </strong>
#        27.5 percent (5th highest)
#        <br/>
#        <strong>
#         • Median household income:
#        </strong>
#        $60,656 (17th highest)
#       </p>
#       <figure class="gnt_em gnt_em_img">
#        <img alt="Golden arches logo hanging over convention center floor, with McDonald's booth nearby and many attendees in the hall." class="gnt_em_img_i" data-g-r="lazy" data-gl-src="https://www.gannett-cdn.com/-mm-/3b8b0abcb585d9841e5193c3d072eed1e5ce62bc/c=0-30-580-356/local/-/media/2018/08/14/USATODAY/usatsports/MotleyFool-TMOT-78bb40a6-mcd-convention_large.jpg?width=580&amp;height=326&amp;fit=crop&amp;format=pjpg&amp;auto=webp" decoding="async" style="height:326px"/>
#        <div class="gnt_em_img_ccw gnt_em_img_ccw__cap gnt_em_img_ccw__crd" data-c-caption="Golden arches logo hanging over convention center floor, with McDonald's booth nearby and many attendees in the hall." data-c-credit="McDonald's">
#        </div>
#       </figure>
#       <p class="gnt_ar_b_p">
#        <asset-img uniqueid="247WallSt.com-247WS-491026-f3fc6f13">
#        </asset-img>
#       </p>
#       <h3 class="gnt_ar_b_h2">
#        45. South Dakota
#       </h3>
#       <p class="gnt_ar_b_p">
#        <strong>
#         • No. of McDonald's:
#        </strong>
#        3.4 per 100,000
#        <br/>
#        <strong>
#         • Adult obesity rate:
#        </strong>
#        30.6 percent (18th highest)
#        <br/>
#        <strong>
# ...
# userSync:{syncEnabled:!0,filterSettings:{iframe:{bidders:['colossusssp'],filter:"exclude"},image:{bidders:['colossusssp'],filter:"exclude"}},syncsPerBidder:50}});;a.addAdUnits(da);f.initXCall&&a.requestBids({bidsBackHandler:e,timeout:h.bidTO})}]};;googletag.cmd.push(()=>{let a,b,c,d,e=googletag.pubads();e.enableSingleRequest();e.setTagForChildDirectedTreatment(0);googletag.enableServices();for(a in Q)Q.hasOwnProperty(a)&&!Q[a].cfg.isVideo&&(b=Q[a],b.gptSlot=c=googletag.defineSlot(b.unit,b.sizes,a),c.addService(e),c.setTargeting("position",b.placement),b.adCount&&c.setTargeting("adCount",b.adCount),b.cfg.nolazy&&(l["gnt-x-showload"]&&
# (d=L.getElementById(a))&&(d.style.backgroundColor="blue"),googletag.display(a)))});;;l["gnt-delay-x"]?H(C,1E3):C()}})();;(gnt.v.tb=[{"container":"gnt_tbw_1","mode":"thumbnails-u","placement":"Below Article Thumbnails - Feed Redesign"},{"container":"gnt_tbw_2","mode":"organic-thumbnails-rr-stream","placement":"Right Rail Thumbnails - Organic"}]).o=g$.hp["gnt-enable-tbo"];;;
# if(!gnt.u.su&&!g$.hp['gnt-disable-ht']){;;let r=document.referrer,o=location.origin;if(r=0===r.indexOf(o)&&r.substr(o.length)){let a;(a=r.indexOf("?"))&&-1<a&&(r=r.substr(0,a));(a=r.indexOf("#"))&&-1<a&&(r=r.substr(0,a))}
# if("/"===r||"/news/"===r||"/sports/"===r||"/entertainment/"===r||"/money/"===r)setTimeout(function(){;gnt.addScript("https://c2.taboola.com/nr/usatodaydemo/newsroom.js",!0,function(){g$.ut("gnt tbhtCb")})});;};;;
# {const a=gnt.u;a.getUser();if(a.au){const d=document.querySelector(".gnt_n_us_a");d&&(d.href="https://account."+gnt.data.publicationDomain,a.wn&&d.setAttribute("aria-label","Hi, "+a.wn));}};
# {const a=g$,d=a.vv,g=a.cached,e=a.el.debounce(()=>{g.windowInnerWidth=innerWidth;g.windowInnerHeight=innerHeight;for(const d of a.rh)d()});addEventListener("resize",e);d&&d.addEventListener("resize",e);a.rh=new Set};;
# g$.hp["gnt-disable-scrolljs"]||setTimeout(function(){function a(){const a=g.createElement("script"),k=g$.ua;a.crossOrigin="use-credentials";a.src="https://static.scroll.com/js/scroll"+(d||g$.b.i||-1===k.indexOf("Chrome")&&-1<k.indexOf("Safari")||-1<location.search.indexOf("scroll")?".js":"-smart.js");g.head.appendChild(a)}const d=gnt.u.su,g=document;window.Scroll={config:{detected:d},_q:d?[function(){function a(a){"number"!==typeof a||b===a&&c||(b=a,c||(c=g.querySelector('[title="Scroll features"]')),
# c&&(c.style.zIndex=b?9999998:2147483647));return b}let d=gnt.v,b=0,c;d.sbp&&setTimeout(a,d.sbp);Object.defineProperty(d,"sbp",{get:a,set:a})}]:[]};d?a():g$.run.push(a)});;;gnt.v.ua={c:{"appKey":"RZEjXgPqRKagwt5Ac-2-iw","token":"MTpSWkVqWGdQcVJLYWd3dDVBYy0yLWl3OnpDOGxJVmZwWGVwNklFNEZOTFFzWlU4Sjltajg3djByakQwVmw3NHFzd2c","vapidPublicKey":"BNvJR_SUE9hR-4Bretw3No2z4y_EVNWl2LSkuTmjzkEnkFa-xWk1xdM0xOQyJdG7KdNZ0job9tVy_TAl_E7phO0="},p:2};;gnt.tmpl={navgd:{url:"/global-q1a2z3ZhzAaR2giDUMXUc+QdFj274BQc.min.json",fb:"<div data-g-r=nav_fm style='padding:32px 32px 0 0;font:700 20px/24px \"Unify Sans\",\"Helvetica Neue\",\"Arial Nova\",Helvetica,Arial,sans-serif'>The navigation could not be loaded.</div><div data-g-r=nav_fm style='padding:18px 32px 18px 0;font:16px/18px \"Helvetica Neue\",\"Arial Nova\",Helvetica,Arial,sans-serif'>Please check your internet connection and try again."}};
#         if(0===document.referrer.indexOf(location.origin)){let b,d;for(let a=0,e=document.querySelectorAll("[data-g-r~=base_xbutton]"),f=e.length;a<f;a++)Object.defineProperty(e[a],"href",{configurable:!0,enumerable:!0,get:function(){if(!d){d=!0;const a=sessionStorage.previousFront;if(a)try{const c=JSON.parse(a);c&&(b=c.path)}catch(c){}}b&&this.setAttribute("href",b);Object.defineProperty(this,"href",{configurable:!0,enumerable:!0,value:b||this.getAttribute("href")})}})};
#
#       gnt.data.sfPath="/tangstatic/html/usat/sf-q1a2z3be0d353f.min.html";
#   g$.run.push(function(){g$.registerMod("vp");;g$.hp["gnt-disable-autoplay"]||g$.el.trigger("vp_ap",document.documentElement);});
#
#
#   ;
# gnt.data.tVPS={vIas:"/gannett-web/apps/teal/dist/vendor/ias/ias-3.5.1.min.js",vIma3:"https://imasdk.googleapis.com/js/sdkloader/ima3.js",vIIma:"/gannett-web/apps/teal/dist/teal-ima-a1174258.min.js",vCs:"/gannett-web/apps/teal/dist/vendor/comscore/streamsense-5.1.1.160316.min.js",vICs:"/gannett-web/apps/teal/dist/teal-comscore-f1701de9.min.js",vIGa:"/gannett-web/apps/teal/dist/teal-gcianalytics-4c420e9b.min.js",vHls:"/gannett-web/apps/teal/dist/vendor/hls/hls.0.14.9.min.js",vIHls:"/gannett-web/apps/teal/dist/teal-hls-ec6a0617.min.js",
# tEncore:"/gannett-web/apps/teal/dist/encore-c29e248c.min.js",tShare:"/gannett-web/apps/teal/dist/share-454f9438.min.js",tCntrls:"/gannett-web/apps/teal/dist/controls-a72d7ef9.min.js",tP:"/gannett-web/apps/teal/dist/tealplayer-5aa8c51e.min.js"};
#
# ;g$.ut("gnt bodyendDone");
#   </script>
#   <script async="" onerror="document.querySelectorAll('.gnt__hbd').forEach(e=&gt;e.classList.remove('gnt__hbd'))" src="/tangstatic/js/main-q1a2z3f986af3c.min.js">
#   </script>
#   <script data-tmpl-key="navgdp" type="gnt/tmpl">
#    <div class="gnt_n_dd_oy gnt_n_dd__sz" data-g-r=nav_oy></div><div class="gnt_n_dd gnt_n_dd__sz" data-g-r="nav_dd nav_te nav_ff" tabindex=0></div>|styles|[data-g-s=nav_ao] .gnt_n_dd_bt_svg{transform:rotate(180deg);background:currentColor;fill:#303030}.gnt_n_dd_oy{display:none;left:0;right:0;height:calc(var(--gnt-vh,100vh) - 160px - var(--gnt-sh,0px))}.gnt_n_dd{overscroll-behavior-y:contain;overflow:auto;overflow-x:hidden;box-sizing:border-box;display:none;width:385px;height:calc(var(--gnt-vh,100vh) - 160px - var(--gnt-sh,0px));margin:0 0 0 -20px;padding:7px 20px 0 32px;border-top:5px solid #0098fe;background:#303030;color:#fff}.gnt__hnb .gnt_n_dd__sz{height:calc(var(--gnt-vh,100vh) - 80px - var(--gnt-sh,0px))}[data-g-s=nav_ao] .gnt_n_dd__sz{display:block;position:absolute}
#   </script>
#   <script data-tmpl-key="navse" type="gnt/tmpl">
#    <form class=gnt_n_se_fm data-g-r=nav_dd action=/search/ role=search><input class=gnt_n_se_fm_qr data-g-r=nav_pf name=q placeholder="What can we help you find?" mozactionhint=search enterkeyhint=search aria-label="Search query"/><button class=gnt_n_se_fm_sm data-t-l=${se}|H1Nav|search| aria-label=Submit><svg class=gnt_n_se_fm_sm_svg viewBox="0 0 18 18"><path d="M12.28 9.76H2V7.74h10.28l-2.23-2.31L11.43 4 16 8.75l-4.57 4.75-1.38-1.43 2.23-2.31z"/></svg></button></form>|styles|.gnt_n_se_fm{display:none;align-items:center;justify-content:center;position:absolute;left:0;right:0;height:180px;padding:0 0 15px;border-top:5px solid #0098fe;background:#303030}[data-g-s~=nav_ao] .gnt_n_se_fm{display:flex}.gnt_n_se_fm_qr{width:492px;height:46px;padding:0 50px 0 0;border-style:solid;border-width:0 0 2px;border-color:#fff;border-radius:0;outline:0;background:0 0;color:#fff;font:700 28px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_n_se_fm_qr::placeholder{opacity:1;color:#fff}.gnt_n_se_fm_qr:-webkit-autofill{box-shadow:inset 0 46px #303030;-webkit-text-fill-color:#fff}.gnt_n_se_fm_sm{width:60px;height:50px;border:0;margin:0 -15px 0 -45px;padding:0;outline-offset:-8px;fill:#fff;background:0 0;cursor:pointer}.gnt_n_se_fm_sm:hover{fill:#e0e0e0}.gnt_n_se_fm_sm_svg{width:42px;height:42px;margin-top:3px;stroke:#303030;stroke-width:.5px}
#   </script>
#   <script data-tmpl-key="navus" type="gnt/tmpl">
#    <div class=gnt_n_us_dd data-g-r=nav_dd><div class=gnt_n_us_dd_u><a class=gnt_n_us_dd_a href=https://account.usatoday.com/ data-t-l="|H1Nav|account|manage account">Manage Account</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://user.usatoday.com/user/enewspaper data-t-l="|H1Nav|account|access enewspaper">Access eNewspaper</a> <a class=gnt_n_us_dd_a href=https://profile.usatoday.com/newsletters/manage/ data-t-l=|H1Nav|account|newsletters>Newsletters</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.usatoday.com/pay data-t-l="|H1Nav|account|pay bill">Pay Bill</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.usatoday.com/delivery-issue data-t-l="|H1Nav|account|report delivery issues">Report Delivery Issues</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.usatoday.com/delivery-temporary-stop data-t-l="|H1Nav|account|pause delivery">Pause Delivery</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://cm.usatoday.com/subscriberguide data-t-l="|H1NavTree|account|subscriber guide">Subscriber Guide</a> <a class=gnt_n_us_dd_a href=https://help.usatoday.com data-t-l="|H1Nav|account|help center">Help Center</a> <a class="gnt_n_us_dd_a gnt_n_us_dd_a__li" data-u-sr="reg sub" href="https://user.usatoday.com/USAT-GUP/user/logout/?return-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F" data-t-l="|H1Nav|account|sign out">Sign Out</a></div><div class=gnt_n_us_dd_ac data-u-sr="anon reg"><div class=gnt_n_us_dd_lbl data-u-sr=anon>Have an existing account?</div><a class="gnt_n_us_dd_ba gnt_n_us_dd_ba__hl" data-u-sr=anon rel=nofollow href="https://login.usatoday.com/USAT-GUP/authenticate?success-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F&cancel-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Fbusiness%2F2018%2F09%2F13%2Fmcdonalds-states-most-stores%2F37748287%2F" data-t-l="|H1Nav|account|sign in">Sign In</a><div class=gnt_n_us_dd_lbl>Already have a subscription?</div><a class=gnt_n_us_dd_ba rel=nofollow href=https://cm.usatoday.com/account-activation/ data-t-l="|H1Nav|account|activate account">Activate account</a><div class=gnt_n_us_dd_lbl data-u-sr=anon>Don't have an account?</div><a class="gnt_n_us_dd_ba gnt_n_us_dd_a__li" data-u-sr=anon rel=nofollow href="https://login.usatoday.com/authenticate/?requested-state=create-account&amp;reg_source=CPNAVBAR&amp;reg_medium=ONSITE&amp;reg_campaign=signin&amp;reg_delivery=ux" data-t-l="|H1Nav|account|create account">Create account</a></div></div>|styles|.gnt_n_us_a_w{position:relative}.gnt_n_us_dd{display:none;position:absolute;top:28px;right:25px;padding:14px 0 14px 15px;border-top:5px solid #0098fe;background:#303030}[data-g-s~=nav_ao] .gnt_n_us_dd{display:flex}.gnt_n_us_dd_u{display:flex;flex-direction:column;min-width:165px;padding-right:15px}.gnt_n_us_dd_a{margin:3px auto 4px 3px;padding:0 2px;color:#fff;font:700 14px/18px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;text-decoration:none;white-space:nowrap}.gnt_n_us_dd_a:hover{color:#e0e0e0}.gnt_n_us_dd_ac{padding:0 15px 0 19px;border-left:1px solid #626262}.gnt_n_us_dd_lbl{margin:5px 0 0;color:#fff;font:700 12px/16px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_n_us_dd_ba{display:block;width:192px;margin:3px 0 19px;padding:9px 1px 8px;border:3px solid #1665cf;outline-offset:-1px;color:#fff;font:700 14px/17px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;text-decoration:none;text-align:center}.gnt_n_us_dd_ba__hl{padding:12px 4px 11px!important;border:0!important;background:var(--gnt-bc,#1665cf)}.gnt_n_us_dd_ba:hover{padding:8px 0 7px;border-width:4px;--gnt-bc:#0A32A0}.gnt_n_us_dd_a__li{margin-bottom:6px}
#   </script>
#   <link as="fetch" crossorigin="use-credentials" href="/global-q1a2z3ZhzAaR2giDUMXUc+QdFj274BQc.min.json" rel="preload" type="application/json"/>
#   <link href="//images.taboola.com" rel="dns-prefetch"/>
#   <link href="https://images.taboola.com" rel="preconnect"/>
#   <script type="application/ld+json">
#    [{"@context":"http://schema.org","@type":"NewsArticle","headline":"Is your state 'lovin' it'? A look at where the most McDonald's are located in the US","description":"McDonald’s is America’s largest hamburger chain with about 14,000 stores in the U.S. The concentration of restaurants varies considerably by state.","url":"https://www.usatoday.com/story/money/business/2018/09/13/mcdonalds-states-most-stores/37748287/","mainEntityOfPage":{"@type":"WebPage","@id":"https://247wallst.com/special-report/2018/09/07/states-with-the-most-mcdonalds-2"},"isBasedOn":"https://247wallst.com/special-report/2018/09/07/states-with-the-most-mcdonalds-2","thumbnailUrl":"https://www.gannett-cdn.com/-mm-/d34bb2a5003d1abd1620ced28e44bcf718b0e89f/c=600-0-3521-2921/local/-/media/2018/06/04/USATODAY/USATODAY/636637268331067900-AP-Salute-To-Summer-Parade.jpg?width=150&height=150&fit=crop&format=pjpg&auto=webp","image":{"@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/97c04198b93024709b947d878e17e45707aec4a4/c=0-296-4121-2624/local/-/media/2018/06/04/USATODAY/USATODAY/636637268331067900-AP-Salute-To-Summer-Parade.jpg?width=1600&height=800&fit=crop&format=pjpg&auto=webp","height":800,"width":1600},"datePublished":"2018-09-13T09:00:03Z","dateCreated":"2018-09-13T09:00:03Z","dateModified":"2018-09-13T16:21:42Z","articleSection":"money","publisher":{"@type":"Organization","name":"WLST","logo":{"@type":"ImageObject","url":"https://www.gannett-cdn.com/sites/usatoday/images/site-nav-logo@2x.png","height":80,"width":297}},"author":["Colman Andrews"],"keywords":["ssts:money:business","type:story","tag:McDonald's","tag:Healthy eating","tag:Research","tag:Health Fanaticism","tag:Commitment","tag:Amusement","tag:Happiness","tag:Overall Positive","tag:disease","tag:Medical research","tag:Diabetes","tag:Children's health","tag:Burger King Worldwide"],"metadata":"{\"id\":\"37748287\",\"siteCode\":\"USAT\",\"contentSourceCode\":\"WLST\",\"ssts\":\"money:business\",\"type\":\"story\"}"},{"@context":"http://schema.org","@type":"VideoObject","name":"McDonald’s burgers & fries are reportedly worse now than in 1989","description":"Despite McDonald’s offering healthier options, it’s signature menu items are higher in salt, calories and sugar than they were 30 years ago, according to a report. Buzz 60's Chandra Lanier has the story. Buzz60","thumbnailUrl":"https://media.gannett-cdn.com/29906170001/29906170001_5751411761001_5751405766001-vs.jpg?pubId=29906170001&width=1280&height=720&format=pjpg&auto=webp","uploadDate":"2018-03-14T16:58:09Z"},{"@context":"http://schema.org","@type":"VideoObject","name":"5 ways McDonald's tricks you into ordering more food","description":"McDonald's uses a number of subliminal techniques to get you to spend more at their restaurants. Buzz60","thumbnailUrl":"https://media.gannett-cdn.com/29906170001/29906170001_5760346498001_5760345568001-vs.jpg?pubId=29906170001&width=1280&height=720&format=pjpg&auto=webp","uploadDate":"2018-03-29T14:30:50Z"},{"@context":"http://schema.org","@type":"VideoObject","name":"Wisconsin man eats 30,000th Big Mac","description":"A retired Wisconsin prison guard ate his 30,000th Big Mac. 64-year-old Don Gorske of Fond du Lac recorded the milestone at a local McDonald's on Friday. Gorske says he's eaten at least one Big Mac almost every day since May 17, 1972. (May 7) AP","thumbnailUrl":"https://media.gannett-cdn.com/29906170001/29906170001_5781265966001_5781260684001-vs.jpg?pubId=29906170001&width=1280&height=720&format=pjpg&auto=webp","uploadDate":"2018-05-07T10:40:09Z"},{"@context":"http://schema.org","@type":"VideoObject","name":"Fast food chains' buzzword: Sustainability","description":"Chains like Starbucks, McDonald's and Dunkin' Donuts are getting on the bandwagon to cutdown on packaging waste. Video by Robert Hanashiro, USA TODAY","thumbnailUrl":"https://media.gannett-cdn.com/29906170001/29906170001_5785947044001_5785924094001-vs.jpg?pubId=29906170001&width=1280&height=720&format=pjpg&auto=webp", ...
#   </script>
#  </body>
# </html>

# %%
#h3 class="gnt_ar_b_h2"
soup.find_all('h3', attrs={'class' : "gnt_ar_b_h2"})[0:50]
# Out:
# [<h3 class="gnt_ar_b_h2">50. Rhode Island</h3>,
#  <h3 class="gnt_ar_b_h2">49. New Jersey</h3>,
#  <h3 class="gnt_ar_b_h2">48. New York</h3>,
#  <h3 class="gnt_ar_b_h2">47. California</h3>,
#  <h3 class="gnt_ar_b_h2">46. North Dakota</h3>,
#  <h3 class="gnt_ar_b_h2">45. South Dakota</h3>,
#  <h3 class="gnt_ar_b_h2">44. Massachusetts</h3>,
#  <h3 class="gnt_ar_b_h2">43. Washington</h3>,
#  <h3 class="gnt_ar_b_h2">42. Idaho</h3>,
#  <h3 class="gnt_ar_b_h2">41. Utah</h3>,
#  <h3 class="gnt_ar_b_h2">40. Colorado</h3>,
#  <h3 class="gnt_ar_b_h2">39. Pennsylvania</h3>,
#  <h3 class="gnt_ar_b_h2">38. Delaware</h3>,
#  <h3 class="gnt_ar_b_h2">37. Connecticut</h3>,
#  <h3 class="gnt_ar_b_h2">36. Oregon</h3>,
#  <h3 class="gnt_ar_b_h2">35. New Hampshire</h3>,
#  <h3 class="gnt_ar_b_h2">34. Minnesota</h3>,
#  <h3 class="gnt_ar_b_h2">33. Nebraska</h3>,
#  <h3 class="gnt_ar_b_h2">32. Arizona</h3>,
#  <h3 class="gnt_ar_b_h2">31. Vermont</h3>,
#  <h3 class="gnt_ar_b_h2">30. Alaska</h3>,
#  <h3 class="gnt_ar_b_h2">29. Texas</h3>,
#  <h3 class="gnt_ar_b_h2">28. Florida</h3>,
#  <h3 class="gnt_ar_b_h2">27. Georgia</h3>,
#  <h3 class="gnt_ar_b_h2">26. Montana</h3>,
#  <h3 class="gnt_ar_b_h2">25. South Carolina</h3>,
#  <h3 class="gnt_ar_b_h2">24. Maine</h3>,
#  <h3 class="gnt_ar_b_h2">23. Virginia</h3>,
#  <h3 class="gnt_ar_b_h2">22. Iowa</h3>,
#  <h3 class="gnt_ar_b_h2">21. North Carolina</h3>,
#  <h3 class="gnt_ar_b_h2">20. Maryland</h3>,
#  <h3 class="gnt_ar_b_h2">19. Nevada</h3>,
#  <h3 class="gnt_ar_b_h2">18. Mississippi</h3>,
#  <h3 class="gnt_ar_b_h2">17. Tennessee</h3>,
#  <h3 class="gnt_ar_b_h2">16. New Mexico</h3>,
#  <h3 class="gnt_ar_b_h2">15. Wyoming</h3>,
#  <h3 class="gnt_ar_b_h2">14. Alabama</h3>,
#  <h3 class="gnt_ar_b_h2">13. Kansas</h3>,
#  <h3 class="gnt_ar_b_h2">12. Louisiana</h3>,
#  <h3 class="gnt_ar_b_h2">11. Missouri</h3>,
#  <h3 class="gnt_ar_b_h2">10. Wisconsin</h3>,
#  <h3 class="gnt_ar_b_h2">9. Hawaii</h3>,
#  <h3 class="gnt_ar_b_h2">8. Illinois</h3>,
#  <h3 class="gnt_ar_b_h2">7. Oklahoma</h3>,
#  <h3 class="gnt_ar_b_h2">6. Indiana</h3>,
#  <h3 class="gnt_ar_b_h2">5. Ohio</h3>,
#  <h3 class="gnt_ar_b_h2">4. Michigan</h3>,
#  <h3 class="gnt_ar_b_h2">3. Kentucky</h3>,
#  <h3 class="gnt_ar_b_h2">2. West Virginia</h3>,
#  <h3 class="gnt_ar_b_h2">1. Arkansas</h3>]

# %%
for a in soup.find_all('h3', attrs={'class' : "gnt_ar_b_h2"})[0:50]:
  print(a.string)
# Out:
# 50. Rhode Island
# 49. New Jersey
# 48. New York
# 47. California
# 46. North Dakota
# 45. South Dakota
# 44. Massachusetts
# 43. Washington
# 42. Idaho
# 41. Utah
# 40. Colorado
# 39. Pennsylvania
# 38. Delaware
# 37. Connecticut
# 36. Oregon
# 35. New Hampshire
# 34. Minnesota
# 33. Nebraska
# 32. Arizona
# 31. Vermont
# 30. Alaska
# 29. Texas
# 28. Florida
# 27. Georgia
# 26. Montana
# 25. South Carolina
# 24. Maine
# 23. Virginia
# 22. Iowa
# 21. North Carolina
# 20. Maryland
# 19. Nevada
# 18. Mississippi
# 17. Tennessee
# 16. New Mexico
# 15. Wyoming
# 14. Alabama
# 13. Kansas
# 12. Louisiana
# 11. Missouri
# 10. Wisconsin
# 9. Hawaii
# 8. Illinois
# 7. Oklahoma
# 6. Indiana
# 5. Ohio
# 4. Michigan
# 3. Kentucky
# 2. West Virginia
# 1. Arkansas

# %%
type(a)
# Out:
# bs4.element.Tag

# %%
states = []
for a in soup.find_all('h3', attrs={'class' : "gnt_ar_b_h2"})[0:50]:
    states.append(a.string)
print(states)
# Out:
# ['50. Rhode Island', '49. New Jersey', '48. New York', '47. California', '46. North Dakota', '45. South Dakota', '44. Massachusetts', '43. Washington', '42. Idaho', '41. Utah', '40. Colorado', '39. Pennsylvania', '38. Delaware', '37. Connecticut', '36. Oregon', '35. New Hampshire', '34. Minnesota', '33. Nebraska', '32. Arizona', '31. Vermont', '30. Alaska', '29. Texas', '28. Florida', '27. Georgia', '26. Montana', '25. South Carolina', '24. Maine', '23. Virginia', '22. Iowa', '21. North Carolina', '20. Maryland', '19. Nevada', '18. Mississippi', '17. Tennessee', '16. New Mexico', '15. Wyoming', '14. Alabama', '13. Kansas', '12. Louisiana', '11. Missouri', '10. Wisconsin', '9. Hawaii', '8. Illinois', '7. Oklahoma', '6. Indiana', '5. Ohio', '4. Michigan', '3. Kentucky', '2. West Virginia', '1. Arkansas']

# %%
type(states)
# Out:
# list

# %%
soup.find_all('p', attrs={'class' : "gnt_ar_b_p"})
# Out:
# [<p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-a0dcc61c"></asset-img></p>,
#  <p class="gnt_ar_b_p">McDonald’s (NYSE: MCD) isn’t America’s largest fast food chain – there are only about 14,000 stores around the country, as opposed to more than 25,000 Subway outlets. It is, however, the largest hamburger chain by far – its nearest competitor, Burger King, has only about 7,500 stores – and the most iconic.</p>,
#  <p class="gnt_ar_b_p">Using data collected from the McDonald’s website, 24/7 Wall Street has identified the number of McDonald’s locations in every state. The tally ranges from 25 in North Dakota to 1,295 in California. The concentration of McDonald's restaurants also varies considerably.</p>,
#  <p class="gnt_ar_b_p">Five of the 10 states with the highest concentrations of McDonald’s per 100,000 residents – West Virginia, Arkansas, Kentucky, Oklahoma, and Michigan – are also among the 10 states with the highest rates of obesity. However, there is virtually no research that establishes a causative link between the availability of Big Macs and Quarter Pounders – or any other fast food – and adverse health outcomes.</p>,
#  <p class="gnt_ar_b_p">A 2011 study in The Journal of Rural Health, for instance, found an association (though not a causative link) between fast food outlets and negative health outcomes in metropolitan areas but not in a rural setting. In 2013, a National Heart, Lung, and Blood Institute’s CARDIA (Coronary Artery Risk Development in Young Adults) study found no association between BMI (body mass index) and density of fast food restaurants and convenience stores. In a systematic review of some 46 studies published between 2005 and 2015 on the relationship between a fast food environment and obesity rates in the United States and abroad by The Journal of Obesity and Weight Loss Therapy, the overwhelming majority found little or no consistent correlation between obesity and fast food.</p>,
#  <p class="gnt_ar_b_p"><strong class="gnt_ar_b_al">More:</strong><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/restaurants/2018/08/25/cities-where-people-go-out-to-eat-all-the-time/37543531/">U.S. cities where people go out to eat all the time</a></p>,
#  <p class="gnt_ar_b_p">On the other hand, a study published in 2015 by two researchers from the Geospatial Sciences Center of Excellence at South Dakota State University discovered that populations in urban settings served primarily by full-service restaurants and grocery stores had a lower obesity rate than those where fast food places and convenience stores predominated.</p>,
#  <p class="gnt_ar_b_p">It is important to remember, though, that there are many other factors other than restaurant choices that may also contribute to obesity and other potentially diet-linked conditions such as cardiovascular disease and diabetes. Low income, high poverty rates, and relative unavailability of fresh fruits and vegetables also contribute to unhealthy lives.</p>,
#  <p class="gnt_ar_b_p">•<strong> No. of McDonald's:</strong> 2.9 per 100,000<br/><strong>• Adult obesity rate:</strong> 27.2 percent (17th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 23.5 percent (20th highest)<br/><strong>• Median household income:</strong> $60,596 (18th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 25.9 percent (12th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 22.1 percent (25th lowest)<br/><strong>• Median household income:</strong> $76,126 (3rd highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-cb98b531"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.1 per 100,000<br/><strong>• Adult obesity rate:</strong> 25.0 percent (8th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 22.4 percent (23rd highest)<br/><strong>• Median household income:</strong> $62,909 (14th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.3 per 100,000<br/><strong>• Adult obesity rate:</strong> 22.7 percent (3rd lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 18.6 percent (9th lowest)<br/><strong>• Median household income:</strong> $67,739 (9th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-79392738"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.3 per 100,000<br/><strong>• Adult obesity rate:</strong> 31.8 percent (12th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 27.5 percent (5th highest)<br/><strong>• Median household income:</strong> $60,656 (17th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-f3fc6f13"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.4 per 100,000<br/><strong>• Adult obesity rate:</strong> 30.6 percent (18th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 26.1 percent (9th highest)<br/><strong>• Median household income:</strong> $54,467 (22nd lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.5 per 100,000<br/><strong>• Adult obesity rate:</strong> 24.3 percent (4th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 18.3 percent (7th lowest)<br/><strong>• Median household income:</strong> $75,297 (4th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-ec18778d"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.6 per 100,000<br/><strong>• Adult obesity rate:</strong> 27.0 percent (15th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 16.9 percent (2nd lowest)<br/><strong>• Median household income:</strong> $67,106 (10th highest)</p>,
#  <p class="gnt_ar_b_p"><strong class="gnt_ar_b_al">More:</strong><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/food/2018/08/29/20-bacon-flavored-foods-the-world-doesnt-need/37624701/">20 bacon-flavored foods the world doesn’t need</a></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.6 per 100,000<br/><strong>• Adult obesity rate:</strong> 28.6 percent (24th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 18.6 percent (9th lowest)<br/><strong>• Median household income:</strong> $51,807 (15th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-e619589d"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.7 per 100,000<br/><strong>• Adult obesity rate:</strong> 25.3 percent (10th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 20.0 percent (15th lowest)<br/><strong>• Median household income:</strong> $65,977 (11th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-391e4c52"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.8 per 100,000<br/><strong>• Adult obesity rate:</strong> 20.5 percent (the lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 17.8 percent (5th lowest)<br/><strong>• Median household income:</strong> $65,685 (12th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 3.9 per 100,000<br/><strong>• Adult obesity rate:</strong> 29.6 percent (22nd highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.2 percent (18th highest)<br/><strong>• Median household income:</strong> $56,907 (23rd highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-31771099"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 30.6 percent (18th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 20.7 percent (17th lowest)<br/><strong>• Median household income:</strong> $61,757 (15th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 25.2 percent (9th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 19.5 percent (14th lowest)<br/><strong>• Median household income:</strong> $73,433 (6th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-c9529e5c"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 27.2 percent (17th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 16.5 percent (the lowest)<br/><strong>• Median household income:</strong> $57,532 (21st highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 27.9 percent (19th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 17.3 percent (3rd lowest)<br/><strong>• Median household income:</strong> $70,936 (7th highest)</p>,
#  <p class="gnt_ar_b_p"><strong class="gnt_ar_b_al">More:</strong><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/economy/2018/08/20/what-your-state-spends-health-care-per-capita/37121541/">What state spends the most on its residents' health care?</a></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.1 per 100,000<br/><strong>• Adult obesity rate:</strong> 27.3 percent (18th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 22.4 percent (23rd highest)<br/><strong>• Median household income:</strong> $65,599 (13th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.1 per 100,000<br/><strong>• Adult obesity rate:</strong> 30.7 percent (17th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.7 percent (11th highest)<br/><strong>• Median household income:</strong> $56,927 (22nd highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-733ac722"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.1 per 100,000<br/><strong>• Adult obesity rate:</strong> 26.7 percent (13th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 20.5 percent (16th lowest)<br/><strong>• Median household income:</strong> $53,558 (20th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-a6b36d20"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 24.7 percent (6th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 17.6 percent (4th lowest)<br/><strong>• Median household income:</strong> $57,677 (20th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-7932b4bc"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 29.4 percent (24th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 18.9 percent (10th lowest)<br/><strong>• Median household income:</strong> $76,440 (2nd highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-d61be59b"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 28.4 percent (22nd lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 19.5 percent (14th lowest)<br/><strong>• Median household income:</strong> $56,565 (25th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.3 per 100,000<br/><strong>• Adult obesity rate:</strong> 25.9 percent (12th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.3 percent (19th lowest)<br/><strong>• Median household income:</strong> $50,860 (13th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-7a8255e6"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.4 per 100,000<br/><strong>• Adult obesity rate:</strong> 30.2 percent (21st highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.7 percent (11th highest)<br/><strong>• Median household income:</strong> $53,559 (21st lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-6433ae82"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.6 per 100,000<br/><strong>• Adult obesity rate:</strong> 25.0 percent (8th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 19.3 percent (12th lowest)<br/><strong>• Median household income:</strong> $50,027 (11th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong class="gnt_ar_b_al">More:</strong><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/economy/2018/07/24/america-happiest-and-most-miserable-states-well-being/36959203/">Which state is America's most miserable? An analysis of well-being</a></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.6 per 100,000<br/><strong>• Adult obesity rate:</strong> 32.0 percent (10th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 25.4 percent (10th highest)<br/><strong>• Median household income:</strong> $49,501 (10th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.6 per 100,000<br/><strong>• Adult obesity rate:</strong> 29.0 percent (25th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 18.3 percent (7th lowest)<br/><strong>• Median household income:</strong> $53,079 (19th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.7 per 100,000<br/><strong>• Adult obesity rate:</strong> 28.3 percent (21st lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.7 percent (24th lowest)<br/><strong>• Median household income:</strong> $68,114 (8th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-fb7c6f88"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.7 per 100,000<br/><strong>• Adult obesity rate:</strong> 31.8 percent (12th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 26.9 percent (6th highest)<br/><strong>• Median household income:</strong> $56,247 (25th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-f544c054"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.8 per 100,000<br/><strong>• Adult obesity rate:</strong> 29.6 percent (22nd highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.6 percent (23rd lowest)<br/><strong>• Median household income:</strong> $50,584 (12th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-49c822e0"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.8 per 100,000<br/><strong>• Adult obesity rate:</strong> 29.2 percent (25th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.3 percent (19th lowest)<br/><strong>• Median household income:</strong> $78,945 (the highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.8 per 100,000<br/><strong>• Adult obesity rate:</strong> 26.8 percent (14th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 19.2 percent (11th lowest)<br/><strong>• Median household income:</strong> $55,180 (24th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.9 per 100,000<br/><strong>• Adult obesity rate:</strong> 35.3 percent (2nd highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 31.2 percent (the highest)<br/><strong>• Median household income:</strong> $41,754 (the lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 4.9 per 100,000<br/><strong>• Adult obesity rate:</strong> 32.4 percent (8th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 22.6 percent (22nd highest)<br/><strong>• Median household income:</strong> $48,547 (8th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong class="gnt_ar_b_al">More:</strong><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/2018/07/11/50-worst-product-flops-of-all-time/36734837/">Historic blunders: 50 worst product flops of all time</a></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 24.4 percent (5th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.5 percent (22nd lowest)<br/><strong>• Median household income:</strong> $46,748 (7th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-c0ccd744"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 28.5 percent (23rd lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.5 percent (22nd lowest)<br/><strong>• Median household income:</strong> $59,882 (19th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-6701054c"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.0 per 100,000<br/><strong>• Adult obesity rate:</strong> 34.7 percent (3rd highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 27.8 percent (4th highest)<br/><strong>• Median household income:</strong> $46,257 (5th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.1 per 100,000<br/><strong>• Adult obesity rate:</strong> 32.4 percent (8th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 22.3 percent (25th highest)<br/><strong>• Median household income:</strong> $54,935 (23rd lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-5d0b643c"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.1 per 100,000<br/><strong>• Adult obesity rate:</strong> 34.7 percent (3rd highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 31.0 percent (2nd highest)<br/><strong>• Median household income:</strong> $45,146 (4th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 31.8 percent (12th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 23.3 percent (21st highest)<br/><strong>• Median household income:</strong> $51,746 (14th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-9cf1627b"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 30.6 percent (18th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.0 percent (19th highest)<br/><strong>• Median household income:</strong> $56,811 (24th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-f1bb338a"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 22.3 percent (2nd lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 21.4 percent (20th lowest)<br/><strong>• Median household income:</strong> $74,511 (5th highest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 28.0 percent (20th lowest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.3 percent (17th highest)<br/><strong>• Median household income:</strong> $60,960 (16th highest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-195260dc"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 33.2 percent (7th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.5 percent (16th highest)<br/><strong>• Median household income:</strong> $49,176 (9th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.2 per 100,000<br/><strong>• Adult obesity rate:</strong> 32.0 percent (10th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 26.7 percent (7th highest)<br/><strong>• Median household income:</strong> $52,314 (16th lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-549ac1d7"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.3 per 100,000<br/><strong>• Adult obesity rate:</strong> 31.6 percent (15th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.7 percent (11th highest)<br/><strong>• Median household income:</strong> $52,334 (17th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.5 per 100,000<br/><strong>• Adult obesity rate:</strong> 31.3 percent (16th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.7 percent (11th highest)<br/><strong>• Median household income:</strong> $52,492 (18th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.7 per 100,000<br/><strong>• Adult obesity rate:</strong> 33.7 percent (6th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 24.6 percent (15th highest)<br/><strong>• Median household income:</strong> $46,659 (6th lowest)</p>,
#  <p class="gnt_ar_b_p"><strong class="gnt_ar_b_al">More:</strong><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://www.usatoday.com/story/money/business/2018/06/28/manufacturers-bringing-most-jobs-back-to-america/36438051/">Which manufacturers are bringing the most jobs back to America?</a></p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-98ac5ab2"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.7 per 100,000<br/><strong>• Adult obesity rate:</strong> 35.5 percent (the highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 26.5 percent (8th highest)<br/><strong>• Median household income:</strong> $43,385 (2nd lowest)</p>,
#  <p class="gnt_ar_b_p"><asset-img uniqueid="247WallSt.com-247WS-491026-d20aada5"></asset-img></p>,
#  <p class="gnt_ar_b_p"><strong>• No. of McDonald's:</strong> 5.8 per 100,000<br/><strong>• Adult obesity rate:</strong> 34.6 percent (5th highest)<br/><strong>• Pct. consuming vegetables less than daily:</strong> 28.1 percent (3rd highest)<br/><strong>• Median household income:</strong> $44,334 (3rd lowest)</p>,
#  <p class="gnt_ar_b_p">For its part, McDonald’s, while defending itself against accusations of targeting children and minority communities with its advertising, has seemingly acknowledged the public perception that its food has deleterious effects on communities. In 2012, the company agreed to provide nutritional information on its menus. In 2013, the chain announced that it was partnering with the Alliance for a Healthier Generation, founded by the American Heart Association and the Clinton Foundation to address childhood obesity and establish a system “that makes the healthy choice the easy choice.”</p>,
#  <p class="gnt_ar_b_p">Among the commitments McDonald’s offered were to feature only water, milk, or juice on Happy Meal menu boards and child-directed advertising; to offer salad or a fruit or vegetable option as a substitute for fries in value meals; and to include a “fun” nutrition or well-being message in all external advertising aimed at children. It should be noted, however, that the chain plans to implement these initiatives in only 20 major markets, and it has given itself until 2020 to do so.</p>,
#  <p class="gnt_ar_b_p">In compiling our data, we included not just the number of McDonald’s locations in each state, but also the number of locations per 100,000 residents – the concentration of McDonald's stores ranges from 5.76 per 100,000 residents in first-place Arkansas to 2.93 in last-place Rhode Island. We also included obesity rates, vegetable consumption rates, and median income. In general, states with greater concentrations of McDonald’s tend to have lower median incomes and report worse health outcomes than those with smaller McDonald’s concentrations.</p>,
#  <p class="gnt_ar_b_p">Interestingly, the number of McDonald’s around the country is shrinking. We found 13,948 of them this year, down from 15,828 in 2016. This may be due in part to a company decision to discourage so-called “mom and pop” franchisees in favor of larger operations. The chain has also experienced declining customer traffic in the United States in recent years.</p>,
#  <p class="gnt_ar_b_p">Only five states have more McDonald’s today than they did two years ago, with the most significant growth, 13.8 percent, coming in Hawaii. In most states, however, the number of locations dropped considerably between 2016 and this year. Leading the downward trend is Rhode Island, where the number of McDonald's restaurants fell from 44 in 2016 to only 31 this year, a nearly 30 percent decline. Close on the Ocean State’s heels was Ohio, where the decline was 25.2 percent, from 823 locations to 616.</p>,
#  <p class="gnt_ar_b_p">Don’t worry, though: Those Golden Arches aren’t likely to go anywhere soon, and there are still 4.28 McDonald’s for every 100,000 Americans nationwide.</p>,
#  <p class="gnt_ar_b_p">To determine the states with the most McDonald’s, 24/7 Wall Street calculated the number of McDonald’s locations per 100,000 residents with data from the McDonald’s online restaurant locator. Data on population came from the U.S. Census Bureau and is for 2017. Data on median household income came from the Census Bureau’s 2016 American Community Survey. Obesity data came from County Health Rankings &amp; Roadmaps, a collaboration between the Robert Wood Johnson Foundation and the University of Wisconsin Population Health Institute. Data on the percentage of adults who consume fruit and vegetables less than once a day came from the Centers for Disease Control and Prevention and is for 2015. All data is for the most recent period available.</p>,
#  <p class="gnt_ar_b_p"><em><a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="http://247wallst.com/">24/7 Wall Street</a> is a USA TODAY content partner offering financial news and commentary. Its content is produced independently of USA TODAY.</em></p>]

# %%
#soup = BeautifulSoup(page.content)
# mcd = soup('body')[0]
# mcd_no.next_sibling = mcd.find('b',text="No. of McDonald's:")
#print(soup.find(text="No. of McDonald's:").next('strong').contents[0])
mcd = soup.find(text="No. of McDonald's:")
# b_tag = address.parent
# td_tag = b_tag.parent
mcd_no = mcd.next('strong')
print(mcd_no.contents[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-59ab6237458f> in <module>
#       6 # b_tag = address.parent
#       7 # td_tag = b_tag.parent
# ----> 8 mcd_no = mcd.next('strong')
#       9 print(mcd_no.contents[0])
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %%
# mcd = soup.find(text=re.compile(r"No. of McDonald's:"))
# print(mcd.nextSibling)
# Out:
# None

# %% [markdown]
# ### Step 3: Convert the Result to a pandas DataFrame
#
# Once you have created a DataFrame, take a look at the results and see if there are any significant correlations between the variables.

# %%
# Your code here
