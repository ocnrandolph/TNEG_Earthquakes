# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
# %matplotlib inline
import requests
import json
from urllib.request import urlretrieve
from bs4 import BeautifulSoup
from collections import defaultdict

# %%
# read in csv file, remove first 3 rows and last 5 rows
tn_hous = pd.read_csv('../data/us_census_tn_housing_units_by_county_2010_2019.csv', skiprows=3, skipfooter=5, engine='python')
tn_hous.tail(10)
# Out:
#                        Unnamed: 0  Census Estimates Base    2010    2011  \
# 86      .Unicoi County, Tennessee   8,830          8,830   8,832   8,841
# 87       .Union County, Tennessee   8,958          8,959   8,974   9,042
# 88   .Van Buren County, Tennessee   2,663          2,665   2,666   2,669
# 89      .Warren County, Tennessee  17,821         17,817  17,821  17,825
# 90  .Washington County, Tennessee  57,254         57,283  57,358  57,826
# 91       .Wayne County, Tennessee   7,287          7,288   7,291   7,303
# 92     .Weakley County, Tennessee  15,495         15,492  15,500  15,533
# 93       .White County, Tennessee  11,511         11,517  11,522  11,575
# 94  .Williamson County, Tennessee  68,498         68,531  68,653  69,295
# 95      .Wilson County, Tennessee  45,568         45,587  45,702  46,558
#
#       2012    2013    2014    2015    2016    2017    2018    2019
# 86   8,838   8,891   8,892   8,895   8,895   8,911   8,919   8,921
# ...

# %%
#drop all columns except for 2018, 2019
tn_hous = tn_hous.drop(columns = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'], axis=1)
tn_hous.head()
# Out:
#                     Unnamed: 0     Census Estimates Base       2018       2019
# 0                    Tennessee  2,812,133      2,812,141  2,995,928  3,028,213
# 1  .Anderson County, Tennessee     34,717         34,700     35,029     35,143
# 2   .Bedford County, Tennessee     18,360         18,360     19,300     19,531
# 3    .Benton County, Tennessee      8,975          8,975      9,147      9,172
# 4   .Bledsoe County, Tennessee      5,718          5,720      5,785      5,796

# %%
#rename 'Unnamed:0' column to 'County'  
tn_hous.columns = ['County', 'Census', 'Estimates_Base', '2018', '2019']
tn_hous.reset_index()
tn_hous.head()
# Out:
#                         County     Census Estimates_Base       2018       2019
# 0                    Tennessee  2,812,133      2,812,141  2,995,928  3,028,213
# 1  .Anderson County, Tennessee     34,717         34,700     35,029     35,143
# 2   .Bedford County, Tennessee     18,360         18,360     19,300     19,531
# 3    .Benton County, Tennessee      8,975          8,975      9,147      9,172
# 4   .Bledsoe County, Tennessee      5,718          5,720      5,785      5,796

# %%
tn_hous['2019']=tn_hous['2019'].replace(',', '')
tn_hous['2019']=tn_hous['2019'].astype(int)
tn_hous
# Out:
#                            County     Census Estimates_Base       2018  \
# 0                       Tennessee  2,812,133      2,812,141  2,995,928
# 1     .Anderson County, Tennessee     34,717         34,700     35,029
# 2      .Bedford County, Tennessee     18,360         18,360     19,300
# 3       .Benton County, Tennessee      8,975          8,975      9,147
# 4      .Bledsoe County, Tennessee      5,718          5,720      5,785
# ..                            ...        ...            ...        ...
# 91       .Wayne County, Tennessee      7,287          7,288      7,359
# 92     .Weakley County, Tennessee     15,495         15,492     15,617
# 93       .White County, Tennessee     11,511         11,517     11,983
# 94  .Williamson County, Tennessee     68,498         68,531     84,952
# 95      .Wilson County, Tennessee     45,568         45,587     55,112
#
#        2019
# 0   3028213
# 1     35143
# 2     19531
# 3      9172
# 4      5796
# ..      ...
# 91     7366
# ...

# %%
tn_hous.sort_values('2019', ascending = False)
# Out:
#                           County     Census Estimates_Base       2018     2019
# 0                      Tennessee  2,812,133      2,812,141  2,995,928  3028213
# 79     .Shelby County, Tennessee    398,274        398,287    406,116   407273
# 19   .Davidson County, Tennessee    283,978        283,937    319,404   325454
# 47       .Knox County, Tennessee    194,949        194,960    207,861   210085
# 33   .Hamilton County, Tennessee    151,107        151,114    164,131   165494
# ..                           ...        ...            ...        ...      ...
# 34    .Hancock County, Tennessee      3,624          3,621      3,616     3613
# 69    .Pickett County, Tennessee      3,462          3,460      3,519     3526
# 64      .Moore County, Tennessee      2,915          2,909      3,070     3087
# 88  .Van Buren County, Tennessee      2,663          2,665      2,691     2695
# 48       .Lake County, Tennessee      2,598          2,598      2,600     2596
#
# [96 rows x 5 columns]
